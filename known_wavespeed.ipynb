# %%
import numpy as np
import torch
from tqdm import tqdm
from utils import greed_assignment,LAP
from plot_utils import plot_3d
from model import Siren,AssignmentModel
from data_model import traveling_time_dataset_fix_wavespeed
from sgld import SGLD
from ot.lp import wasserstein_1d
import matplotlib.pyplot as plt
import copy
device = torch.device('cuda:3' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# ## Load dataset

# %%
grid_size=32
vmin=0.5
vmax=2.5
n_station=20
V=np.load('data/overthrust.npy')
V=(V-V.min())/(V.max()-V.min())
V=V*(vmax-vmin)+vmin #scale
ttdata=traveling_time_dataset_fix_wavespeed(V,n_station,grid_size) #traveling time dataset

# %%
[fig,ax0,ax1]=plot_3d(V)
coord=ttdata.loc_src_index # coordinates of the source
ax0.scatter3D(coord[:,0],coord[:,1],coord[:,2],s=20,depthshade=0,zorder=1e20,marker=(5, 1),color='orange',label='Station')
_=ax0.legend()

# %% [markdown]
# ## Fit traveling time

# %%
batch_size_siren=1024
first_omega_0=15
hidden_omega_0=15
model_traveltime= Siren(in_features=3, out_features=n_station, hidden_features=512, 
                        hidden_layers=4, outermost_linear=True,first_omega_0=first_omega_0, hidden_omega_0=hidden_omega_0).to(device)
optimizer = torch.optim.Adam(model_traveltime.parameters(), lr=0.00001)
loss_function=torch.nn.MSELoss(reduction='mean')
train_loader = torch.utils.data.DataLoader(ttdata, batch_size=batch_size_siren, shuffle=True,num_workers=8)

# %%
for epoch in range(10000):
    model_traveltime.train()
    loss_batch = 0
    for data in train_loader:
        X = data['in'].float().to(device)
        Y = data['out'].float().to(device)
        Ypred,_= model_traveltime(X)
        loss = loss_function(Y, Ypred)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        loss_batch += loss.item()
    loss_epoch = loss_batch/len(train_loader)
    print(f'Epoch: {epoch:03d}, Train Loss: {loss_epoch:.2E}')
    if loss_epoch<1e-5:
        break
# Out:
# Epoch: 000, Train Loss: 2.01E-01
# Epoch: 001, Train Loss: 4.86E-02
# Epoch: 002, Train Loss: 1.75E-02
# Epoch: 003, Train Loss: 7.76E-03
# Epoch: 004, Train Loss: 4.22E-03
# Epoch: 005, Train Loss: 2.66E-03
# Epoch: 006, Train Loss: 1.85E-03
# Epoch: 007, Train Loss: 1.37E-03
# Epoch: 008, Train Loss: 1.08E-03
# Epoch: 009, Train Loss: 8.78E-04
# Epoch: 010, Train Loss: 7.36E-04
# Epoch: 011, Train Loss: 6.30E-04
# Epoch: 012, Train Loss: 5.48E-04
# Epoch: 013, Train Loss: 4.83E-04
# Epoch: 014, Train Loss: 4.31E-04
# Epoch: 015, Train Loss: 3.88E-04
# Epoch: 016, Train Loss: 3.51E-04
# Epoch: 017, Train Loss: 3.21E-04
# Epoch: 018, Train Loss: 2.94E-04
# Epoch: 019, Train Loss: 2.71E-04
# Epoch: 020, Train Loss: 2.51E-04
# Epoch: 021, Train Loss: 2.33E-04
# Epoch: 022, Train Loss: 2.17E-04
# Epoch: 023, Train Loss: 2.03E-04
# Epoch: 024, Train Loss: 1.91E-04
# Epoch: 025, Train Loss: 1.79E-04
# Epoch: 026, Train Loss: 1.69E-04
# Epoch: 027, Train Loss: 1.59E-04
# Epoch: 028, Train Loss: 1.51E-04
# Epoch: 029, Train Loss: 1.43E-04
# Epoch: 030, Train Loss: 1.36E-04
# Epoch: 031, Train Loss: 1.29E-04
# Epoch: 032, Train Loss: 1.23E-04
# Epoch: 033, Train Loss: 1.17E-04
# Epoch: 034, Train Loss: 1.12E-04
# Epoch: 035, Train Loss: 1.07E-04
# Epoch: 036, Train Loss: 1.03E-04
# Epoch: 037, Train Loss: 9.83E-05
# Epoch: 038, Train Loss: 9.42E-05
# Epoch: 039, Train Loss: 9.05E-05
# Epoch: 040, Train Loss: 8.70E-05
# Epoch: 041, Train Loss: 8.36E-05
# Epoch: 042, Train Loss: 8.06E-05
# Epoch: 043, Train Loss: 7.75E-05
# Epoch: 044, Train Loss: 7.48E-05
# Epoch: 045, Train Loss: 7.22E-05
# Epoch: 046, Train Loss: 6.96E-05
# Epoch: 047, Train Loss: 6.73E-05
# Epoch: 048, Train Loss: 6.50E-05
# Epoch: 049, Train Loss: 6.29E-05
# Epoch: 050, Train Loss: 6.10E-05
# Epoch: 051, Train Loss: 5.91E-05
# Epoch: 052, Train Loss: 5.73E-05
# Epoch: 053, Train Loss: 5.55E-05
# Epoch: 054, Train Loss: 5.39E-05
# Epoch: 055, Train Loss: 5.23E-05
# Epoch: 056, Train Loss: 5.08E-05
# Epoch: 057, Train Loss: 4.93E-05
# Epoch: 058, Train Loss: 4.80E-05
# Epoch: 059, Train Loss: 4.68E-05
# Epoch: 060, Train Loss: 4.55E-05
# Epoch: 061, Train Loss: 4.43E-05
# Epoch: 062, Train Loss: 4.32E-05
# Epoch: 063, Train Loss: 4.22E-05
# Epoch: 064, Train Loss: 4.11E-05
# Epoch: 065, Train Loss: 4.03E-05
# Epoch: 066, Train Loss: 3.91E-05
# Epoch: 067, Train Loss: 3.82E-05
# Epoch: 068, Train Loss: 3.73E-05
# Epoch: 069, Train Loss: 3.64E-05
# Epoch: 070, Train Loss: 3.56E-05
# Epoch: 071, Train Loss: 3.49E-05
# Epoch: 072, Train Loss: 3.42E-05
# Epoch: 073, Train Loss: 3.35E-05
# Epoch: 074, Train Loss: 3.25E-05
# Epoch: 075, Train Loss: 3.20E-05
# Epoch: 076, Train Loss: 3.13E-05
# Epoch: 077, Train Loss: 3.07E-05
# Epoch: 078, Train Loss: 3.01E-05
# Epoch: 079, Train Loss: 2.95E-05
# Epoch: 080, Train Loss: 2.90E-05
# Epoch: 081, Train Loss: 2.83E-05
# Epoch: 082, Train Loss: 2.78E-05
# Epoch: 083, Train Loss: 2.73E-05
# Epoch: 084, Train Loss: 2.68E-05
# Epoch: 085, Train Loss: 2.64E-05
# Epoch: 086, Train Loss: 2.58E-05
# Epoch: 087, Train Loss: 2.56E-05
# Epoch: 088, Train Loss: 2.50E-05
# Epoch: 089, Train Loss: 2.47E-05
# Epoch: 090, Train Loss: 2.42E-05
# Epoch: 091, Train Loss: 2.36E-05
# Epoch: 092, Train Loss: 2.35E-05
# Epoch: 093, Train Loss: 2.32E-05
# Epoch: 094, Train Loss: 2.26E-05
# Epoch: 095, Train Loss: 2.24E-05
# Epoch: 096, Train Loss: 2.21E-05
# Epoch: 097, Train Loss: 2.17E-05
# Epoch: 098, Train Loss: 2.13E-05
# Epoch: 099, Train Loss: 2.09E-05
# Epoch: 100, Train Loss: 2.08E-05
# Epoch: 101, Train Loss: 2.04E-05
# Epoch: 102, Train Loss: 2.05E-05
# Epoch: 103, Train Loss: 2.00E-05
# Epoch: 104, Train Loss: 1.97E-05
# Epoch: 105, Train Loss: 1.96E-05
# Epoch: 106, Train Loss: 1.91E-05
# Epoch: 107, Train Loss: 1.90E-05
# Epoch: 108, Train Loss: 1.86E-05
# Epoch: 109, Train Loss: 1.84E-05
# Epoch: 110, Train Loss: 1.80E-05
# Epoch: 111, Train Loss: 1.82E-05
# Epoch: 112, Train Loss: 1.77E-05
# Epoch: 113, Train Loss: 1.73E-05
# Epoch: 114, Train Loss: 1.73E-05
# Epoch: 115, Train Loss: 1.70E-05
# Epoch: 116, Train Loss: 1.68E-05
# Epoch: 117, Train Loss: 1.65E-05
# Epoch: 118, Train Loss: 1.67E-05
# Epoch: 119, Train Loss: 1.64E-05
# Epoch: 120, Train Loss: 1.61E-05
# Epoch: 121, Train Loss: 1.62E-05
# Epoch: 122, Train Loss: 1.57E-05
# Epoch: 123, Train Loss: 1.57E-05
# Epoch: 124, Train Loss: 1.56E-05
# Epoch: 125, Train Loss: 1.53E-05
# Epoch: 126, Train Loss: 1.55E-05
# Epoch: 127, Train Loss: 1.53E-05
# Epoch: 128, Train Loss: 1.54E-05
# Epoch: 129, Train Loss: 1.48E-05
# Epoch: 130, Train Loss: 1.47E-05
# Epoch: 131, Train Loss: 1.51E-05
# Epoch: 132, Train Loss: 1.51E-05
# Epoch: 133, Train Loss: 1.50E-05
# Epoch: 134, Train Loss: 1.46E-05
# Epoch: 135, Train Loss: 1.41E-05
# Epoch: 136, Train Loss: 1.47E-05
# Epoch: 137, Train Loss: 1.36E-05
# Epoch: 138, Train Loss: 1.37E-05
# Epoch: 139, Train Loss: 1.36E-05
# Epoch: 140, Train Loss: 1.38E-05
# Epoch: 141, Train Loss: 1.37E-05
# Epoch: 142, Train Loss: 1.46E-05
# Epoch: 143, Train Loss: 1.34E-05
# Epoch: 144, Train Loss: 1.31E-05
# Epoch: 145, Train Loss: 1.31E-05
# Epoch: 146, Train Loss: 1.26E-05
# Epoch: 147, Train Loss: 1.28E-05
# Epoch: 148, Train Loss: 1.28E-05
# Epoch: 149, Train Loss: 1.25E-05
# Epoch: 150, Train Loss: 1.29E-05
# Epoch: 151, Train Loss: 1.32E-05
# Epoch: 152, Train Loss: 1.43E-05
# Epoch: 153, Train Loss: 1.29E-05
# Epoch: 154, Train Loss: 1.24E-05
# Epoch: 155, Train Loss: 1.22E-05
# Epoch: 156, Train Loss: 1.24E-05
# Epoch: 157, Train Loss: 1.34E-05
# Epoch: 158, Train Loss: 1.24E-05
# Epoch: 159, Train Loss: 1.16E-05
# Epoch: 160, Train Loss: 1.16E-05
# Epoch: 161, Train Loss: 1.20E-05
# Epoch: 162, Train Loss: 1.18E-05
# Epoch: 163, Train Loss: 1.33E-05
# Epoch: 164, Train Loss: 1.23E-05
# Epoch: 165, Train Loss: 1.14E-05
# Epoch: 166, Train Loss: 1.23E-05
# Epoch: 167, Train Loss: 1.11E-05
# Epoch: 168, Train Loss: 1.12E-05
# Epoch: 169, Train Loss: 1.11E-05
# Epoch: 170, Train Loss: 1.13E-05
# Epoch: 171, Train Loss: 1.15E-05
# Epoch: 172, Train Loss: 1.10E-05
# Epoch: 173, Train Loss: 1.14E-05
# Epoch: 174, Train Loss: 1.10E-05
# Epoch: 175, Train Loss: 1.06E-05
# Epoch: 176, Train Loss: 1.07E-05
# Epoch: 177, Train Loss: 1.14E-05
# Epoch: 178, Train Loss: 1.17E-05
# Epoch: 179, Train Loss: 1.17E-05
# Epoch: 180, Train Loss: 1.06E-05
# Epoch: 181, Train Loss: 1.03E-05
# Epoch: 182, Train Loss: 1.02E-05
# Epoch: 183, Train Loss: 1.13E-05
# Epoch: 184, Train Loss: 1.18E-05
# Epoch: 185, Train Loss: 1.06E-05
# Epoch: 186, Train Loss: 9.94E-06

# %% [markdown]
# ## Generate earthquake dataset

# %%
n_earthquake=8
tau_max=0.1 #1=10s
loc_earthquake_index=np.random.randint(grid_size,size=[n_earthquake,3])
tt=ttdata.travel_time.reshape(n_station,grid_size,grid_size,grid_size)
true_receiver= tt[:,loc_earthquake_index[:,0],loc_earthquake_index[:,1],loc_earthquake_index[:,2]]
loc_earthquake_coord=loc_earthquake_index/(grid_size-1)
time_earthquake = np.random.rand(n_earthquake)*tau_max

## received signal is sorted
true_station_travelingtime=np.zeros_like(true_receiver)
true_station_travelingtime_index=np.zeros_like(true_receiver,dtype=int)
for i in range(n_station):
    true_receiver[i,:]=true_receiver[i,:]+time_earthquake
    true_station_travelingtime[i,:]=np.sort(true_receiver[i,:])
    true_station_travelingtime_index[i,:]=np.argsort(true_receiver[i,:])

# %% [markdown]
# ## Run!

# %%
for try_i in range(1000): # usually need 1~5 trials 
    loc_record_list=[]
    lowest_loss=100000
    updata_lr_flag=True    
    L=0 #dimention of the wave speed, for fixed wave speed, L=0
    batch_size=100
    model_traveltime_=copy.deepcopy(model_traveltime).to(device)
    AModel=AssignmentModel(model_traveltime_, n_station, n_earthquake,tau_max,L=L).to(device)
    optimizer = SGLD(AModel.parameters(), lr=0.01,noise=1e-3)
    loc_earthquake_re=AModel.loc_earthquake.detach().clone().cpu().numpy()
    loc_record_list.append(loc_earthquake_re)
    for epoch in range(30):
        loss_batch = 0
        count=0
        for count in range(batch_size):
            i=np.random.randint(n_station) ## update one station at each time 
            out=AModel().T
            outi=out[i,:]
            Y=torch.tensor(true_station_travelingtime[i,:]).float().to(device)
            loss = wasserstein_1d(outi, Y, p=2)
            loss_batch += loss.item()
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
        loss_epoch = loss_batch/batch_size
        
        ## change hp
        if loss_epoch<0.0002 and updata_lr_flag:
            updata_lr_flag=False
            optimizer = SGLD(AModel.parameters(), lr=0.001,noise=1e-3)            
        
        ## val test
        loc_earthquake_re=AModel.loc_earthquake.detach().clone().cpu().numpy()
        loc_record_list.append(loc_earthquake_re)
        indexB=greed_assignment(loc_earthquake_coord,loc_earthquake_re)  # only check the test perfermance roughly
        loc_error=((loc_earthquake_coord[indexB,:]-loc_earthquake_re)**2).mean()
        time_earthquake_re=AModel.time_earthquake.detach().clone().cpu().numpy()
        time_error=(((time_earthquake[indexB]-time_earthquake_re))**2).mean()
        if loss_epoch <lowest_loss:
            lowest_loss= loss_epoch
            lowest_loss_loc_earthquake_re = loc_earthquake_re
            lowest_loss_time_earthquake_re = time_earthquake_re
            lowest_loss_out = AModel(sort_out=False).clone().detach().cpu().numpy().T
        
        print(f'Try: {try_i:03d},Epoch: {epoch:03d}, Loss: {loss_epoch:.6f}, Loc error: {loc_error:.6f}, Time error: {time_error:.6f}')
    if lowest_loss<0.0002:
            break

## training extra epoachs with a small learning rate to get a better reconstruction.
optimizer = SGLD(AModel.parameters(), lr=0.001,noise=1e-4)            
for epoch in range(50):
    loss_batch = 0
    count=0
    for count in range(batch_size):
        i=np.random.randint(n_station) ## update one station at each time 
        out=AModel().T
        outi=out[i,:]
        Y=torch.tensor(true_station_travelingtime[i,:]).float().to(device)
        loss = wasserstein_1d(outi, Y, p=2)
        loss_batch += loss.item()
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    loss_epoch = loss_batch/batch_size
    
    ## val test
    loc_earthquake_re=AModel.loc_earthquake.detach().clone().cpu().numpy()
    loc_record_list.append(loc_earthquake_re)
    indexB=greed_assignment(loc_earthquake_coord,loc_earthquake_re)  # only check the test perfermance roughly
    loc_error=((loc_earthquake_coord[indexB,:]-loc_earthquake_re)**2).mean()
    time_earthquake_re=AModel.time_earthquake.detach().clone().cpu().numpy()
    time_error=(((time_earthquake[indexB]-time_earthquake_re))**2).mean()
    if loss_epoch <lowest_loss:
        lowest_loss= loss_epoch
        lowest_loss_loc_earthquake_re = loc_earthquake_re
        lowest_loss_time_earthquake_re = time_earthquake_re
        lowest_loss_out = AModel(sort_out=False).clone().detach().cpu().numpy().T
    print(f'Try: {try_i:03d},Epoch: {epoch:03d}, Loss: {loss_epoch:.6f}, Loc error: {loc_error:.6f}, Time error: {time_error:.6f}')
# Out:
# Try: 000,Epoch: 000, Loss: 0.002452, Loc error: 0.026420, Time error: 0.001613
# Try: 000,Epoch: 001, Loss: 0.000826, Loc error: 0.019310, Time error: 0.001570
# Try: 000,Epoch: 002, Loss: 0.001093, Loc error: 0.017278, Time error: 0.001363
# Try: 000,Epoch: 003, Loss: 0.000656, Loc error: 0.004363, Time error: 0.001533
# Try: 000,Epoch: 004, Loss: 0.000108, Loc error: 0.001098, Time error: 0.000647
# Try: 000,Epoch: 005, Loss: 0.000067, Loc error: 0.000951, Time error: 0.000543
# Try: 000,Epoch: 006, Loss: 0.000031, Loc error: 0.000578, Time error: 0.000449
# Try: 000,Epoch: 007, Loss: 0.000028, Loc error: 0.000508, Time error: 0.000409
# Try: 000,Epoch: 008, Loss: 0.000030, Loc error: 0.000372, Time error: 0.000285
# Try: 000,Epoch: 009, Loss: 0.000023, Loc error: 0.000349, Time error: 0.000282
# Try: 000,Epoch: 010, Loss: 0.000023, Loc error: 0.000188, Time error: 0.000236
# Try: 000,Epoch: 011, Loss: 0.000026, Loc error: 0.000311, Time error: 0.000259
# Try: 000,Epoch: 012, Loss: 0.000026, Loc error: 0.000312, Time error: 0.000188
# Try: 000,Epoch: 013, Loss: 0.000028, Loc error: 0.000562, Time error: 0.000274
# Try: 000,Epoch: 014, Loss: 0.000030, Loc error: 0.000874, Time error: 0.000342
# Try: 000,Epoch: 015, Loss: 0.000035, Loc error: 0.000866, Time error: 0.000549
# Try: 000,Epoch: 016, Loss: 0.000035, Loc error: 0.000721, Time error: 0.000423
# Try: 000,Epoch: 017, Loss: 0.000032, Loc error: 0.000793, Time error: 0.000257
# Try: 000,Epoch: 018, Loss: 0.000030, Loc error: 0.000600, Time error: 0.000328
# Try: 000,Epoch: 019, Loss: 0.000026, Loc error: 0.000336, Time error: 0.000222
# Try: 000,Epoch: 020, Loss: 0.000025, Loc error: 0.000290, Time error: 0.000221
# Try: 000,Epoch: 021, Loss: 0.000028, Loc error: 0.000355, Time error: 0.000273
# Try: 000,Epoch: 022, Loss: 0.000031, Loc error: 0.000386, Time error: 0.000249
# Try: 000,Epoch: 023, Loss: 0.000025, Loc error: 0.000325, Time error: 0.000198
# Try: 000,Epoch: 024, Loss: 0.000023, Loc error: 0.000305, Time error: 0.000167
# Try: 000,Epoch: 025, Loss: 0.000023, Loc error: 0.000331, Time error: 0.000278
# Try: 000,Epoch: 026, Loss: 0.000020, Loc error: 0.000179, Time error: 0.000170
# Try: 000,Epoch: 027, Loss: 0.000020, Loc error: 0.000344, Time error: 0.000242
# Try: 000,Epoch: 028, Loss: 0.000020, Loc error: 0.000272, Time error: 0.000147
# Try: 000,Epoch: 029, Loss: 0.000021, Loc error: 0.000174, Time error: 0.000107
# Try: 000,Epoch: 000, Loss: 0.000015, Loc error: 0.000091, Time error: 0.000099
# Try: 000,Epoch: 001, Loss: 0.000007, Loc error: 0.000077, Time error: 0.000087
# Try: 000,Epoch: 002, Loss: 0.000007, Loc error: 0.000054, Time error: 0.000077
# Try: 000,Epoch: 003, Loss: 0.000008, Loc error: 0.000056, Time error: 0.000082
# Try: 000,Epoch: 004, Loss: 0.000007, Loc error: 0.000048, Time error: 0.000093
# Try: 000,Epoch: 005, Loss: 0.000007, Loc error: 0.000065, Time error: 0.000079
# Try: 000,Epoch: 006, Loss: 0.000008, Loc error: 0.000055, Time error: 0.000078
# Try: 000,Epoch: 007, Loss: 0.000007, Loc error: 0.000051, Time error: 0.000070
# Try: 000,Epoch: 008, Loss: 0.000006, Loc error: 0.000062, Time error: 0.000088
# Try: 000,Epoch: 009, Loss: 0.000007, Loc error: 0.000057, Time error: 0.000075
# Try: 000,Epoch: 010, Loss: 0.000007, Loc error: 0.000044, Time error: 0.000095
# Try: 000,Epoch: 011, Loss: 0.000007, Loc error: 0.000042, Time error: 0.000070
# Try: 000,Epoch: 012, Loss: 0.000007, Loc error: 0.000048, Time error: 0.000065
# Try: 000,Epoch: 013, Loss: 0.000007, Loc error: 0.000048, Time error: 0.000083
# Try: 000,Epoch: 014, Loss: 0.000007, Loc error: 0.000049, Time error: 0.000064
# Try: 000,Epoch: 015, Loss: 0.000007, Loc error: 0.000048, Time error: 0.000075
# Try: 000,Epoch: 016, Loss: 0.000006, Loc error: 0.000046, Time error: 0.000063
# Try: 000,Epoch: 017, Loss: 0.000006, Loc error: 0.000050, Time error: 0.000075
# Try: 000,Epoch: 018, Loss: 0.000007, Loc error: 0.000048, Time error: 0.000056
# Try: 000,Epoch: 019, Loss: 0.000007, Loc error: 0.000036, Time error: 0.000064
# Try: 000,Epoch: 020, Loss: 0.000007, Loc error: 0.000039, Time error: 0.000047
# Try: 000,Epoch: 021, Loss: 0.000007, Loc error: 0.000047, Time error: 0.000073
# Try: 000,Epoch: 022, Loss: 0.000007, Loc error: 0.000051, Time error: 0.000060
# Try: 000,Epoch: 023, Loss: 0.000007, Loc error: 0.000043, Time error: 0.000062
# Try: 000,Epoch: 024, Loss: 0.000007, Loc error: 0.000050, Time error: 0.000064
# Try: 000,Epoch: 025, Loss: 0.000007, Loc error: 0.000048, Time error: 0.000073
# Try: 000,Epoch: 026, Loss: 0.000007, Loc error: 0.000051, Time error: 0.000066
# Try: 000,Epoch: 027, Loss: 0.000007, Loc error: 0.000034, Time error: 0.000093
# Try: 000,Epoch: 028, Loss: 0.000007, Loc error: 0.000046, Time error: 0.000084
# Try: 000,Epoch: 029, Loss: 0.000007, Loc error: 0.000054, Time error: 0.000076
# Try: 000,Epoch: 030, Loss: 0.000007, Loc error: 0.000060, Time error: 0.000082
# Try: 000,Epoch: 031, Loss: 0.000006, Loc error: 0.000049, Time error: 0.000083
# Try: 000,Epoch: 032, Loss: 0.000006, Loc error: 0.000060, Time error: 0.000100
# Try: 000,Epoch: 033, Loss: 0.000006, Loc error: 0.000058, Time error: 0.000082
# Try: 000,Epoch: 034, Loss: 0.000007, Loc error: 0.000060, Time error: 0.000086
# Try: 000,Epoch: 035, Loss: 0.000007, Loc error: 0.000051, Time error: 0.000079
# Try: 000,Epoch: 036, Loss: 0.000006, Loc error: 0.000046, Time error: 0.000071
# Try: 000,Epoch: 037, Loss: 0.000007, Loc error: 0.000058, Time error: 0.000072
# Try: 000,Epoch: 038, Loss: 0.000007, Loc error: 0.000057, Time error: 0.000077
# Try: 000,Epoch: 039, Loss: 0.000006, Loc error: 0.000057, Time error: 0.000079
# Try: 000,Epoch: 040, Loss: 0.000007, Loc error: 0.000062, Time error: 0.000090
# Try: 000,Epoch: 041, Loss: 0.000007, Loc error: 0.000049, Time error: 0.000078
# Try: 000,Epoch: 042, Loss: 0.000007, Loc error: 0.000058, Time error: 0.000072
# Try: 000,Epoch: 043, Loss: 0.000007, Loc error: 0.000046, Time error: 0.000084
# Try: 000,Epoch: 044, Loss: 0.000006, Loc error: 0.000054, Time error: 0.000060
# Try: 000,Epoch: 045, Loss: 0.000007, Loc error: 0.000053, Time error: 0.000070
# Try: 000,Epoch: 046, Loss: 0.000006, Loc error: 0.000048, Time error: 0.000068
# Try: 000,Epoch: 047, Loss: 0.000007, Loc error: 0.000047, Time error: 0.000072
# Try: 000,Epoch: 048, Loss: 0.000007, Loc error: 0.000043, Time error: 0.000079
# Try: 000,Epoch: 049, Loss: 0.000007, Loc error: 0.000058, Time error: 0.000077

# %%
assignment_function=LAP

plt.rcParams.update({'font.size': 14})
indexB=assignment_function(loc_earthquake_coord,loc_earthquake_re)  #get a order for the plot
plt.figure(figsize=(6.4, 4.8))
Crange=range(n_earthquake)
xaxis_max=lowest_loss_out.max()*1.1
cmap = plt.cm.get_cmap('Dark2', n_earthquake)
correct_rate=0
for i in range(n_station):
    yaxis_i=np.ones(n_earthquake)*i
    tx=true_station_travelingtime[i,]
    ti=true_station_travelingtime_index[i,:]
    out=lowest_loss_out[i,:]
    indexBi=assignment_function(out.reshape(-1,1),tx.reshape(-1,1))
    plt.plot([0,xaxis_max*9.5],[i,i],'-b',alpha=0.1)
    plt.scatter(tx*10,yaxis_i,marker='o', facecolors='none',s=50,alpha=1,edgecolors=cmap(ti[Crange]))
    plt.scatter(tx*10,yaxis_i,cmap=cmap,c=indexB[indexBi[Crange]],s=10,alpha=1)
    correct_rate+=np.mean(ti[Crange]==indexB[indexBi[Crange]])
cbar=plt.colorbar()
plt.xlabel('Time (s)')
plt.yticks([])
cbar.ax.tick_params(length=0)
cbar.set_ticks([])
print('Accuracy:',correct_rate/n_station)
# Out:
# Accuracy: 0.95

# %% [markdown]
# # Plot trajectory

# %%
import matplotlib as mpl
from mpl_toolkits.mplot3d.art3d import Line3DCollection
from matplotlib.cm import ScalarMappable
plt.rcParams.update({'font.size': 10})
cmap=plt.cm.jet
bar_label='Wave speed (km/s)'
zoom_scale=1
nx,ny,nz=grid_size,grid_size,grid_size

X, Y, Z = np.meshgrid(np.arange(nx), np.arange(ny), -np.arange(nz))
data = np.transpose(V,[1,0,2])*10
#data=np.array(c)
kw = {
    'vmin': 5,
    'vmax': 25,
}
norm = mpl.colors.Normalize(**kw)
fig = plt.figure(figsize=(8, 6))
ax1 = fig.add_subplot(111, projection='3d',computed_zorder=False)
# Plot contour surfaces
ax1.plot_surface(
    X[:, :, -1], Y[:, :, -1], Z[:,:,-1],rstride=1, cstride=1, facecolors=cmap(norm(data[:, :, -1])),shade=False)
ax1.plot_surface(
    X[-1, :, :], Y[-1, :, :], Z[-1,:,:],rstride=1, cstride=1, facecolors=cmap(norm(data[-1, :, :])),shade=False)
ax1.plot_surface(
    X[:, 0, :], Y[:, 0, :], Z[:,0,:],rstride=1, cstride=1, facecolors=cmap(norm(data[:, 0, :])),shade=False)


xmin, xmax = X.min(), X.max()
ymin, ymax = Y.min(), Y.max()
zmin, zmax = Z.min(), Z.max()
ax1.set(xlim=[xmin, xmax], ylim=[ymin, ymax], zlim=[zmin, zmax])



# Plot edges
edges_kw = dict(color='0.2', linewidth=2, zorder=1e2)
ax1.plot([xmin, xmin], [ymin, ymax], [zmin,zmin], **edges_kw)
ax1.plot([xmin, xmax], [ymax, ymax], [zmin,zmin], **edges_kw)
ax1.plot([xmin, xmin], [ymax, ymax], [zmin, zmax], **edges_kw)



# Set labels and zticks
ax1.set(
    xlabel='X (km)',
    ylabel='Y (km)',
    zlabel='Z (km)',
    zticks=[0,-int(nz/4),-int(nz/4*2),-int(nz/4*3),-nz],
    zticklabels=[0,-25, -50,-75,-100],
    xticks=[0,int(nx/4),int(nx/4*2),int(nx/4*3),nx],
    xticklabels=[0, 25,50,75,100],
    yticks=[0,int(nx/4),int(ny/4*2),int(ny/4*3),ny],
    yticklabels=[0, 25,50,75,100],
)

ax1.view_init(10, -30, 0)
ax1.set_box_aspect(None, zoom=1)




#sc=ax1.scatter3D(trj[:,0]*(grid_size-1),trj[:,1]*(grid_size-1),-trj[:,2]*(grid_size-1),s=20,depthshade=0,zorder=1e20,cmap='binary',c=range(trj.shape[0]),edgecolors='black')

init_re=loc_record_list[0]
ax1.scatter(init_re[:,0]*(grid_size-1),init_re[:,1]*(grid_size-1),-init_re[:,2]*(grid_size-1),s=30,color='black',marker='s',label='Earthquake',depthshade=0,edgecolors='black',zorder=1e11)
ax1.scatter(loc_earthquake_re[:,0]*(grid_size-1),loc_earthquake_re[:,1]*(grid_size-1),-loc_earthquake_re[:,2]*(grid_size-1),s=30,color='white',marker='o',label='Earthquake',depthshade=0,edgecolors='black',zorder=1e21)
cmap = plt.cm.get_cmap('gray')
loc_np=np.array(loc_record_list)

kw = {
    'vmin': 0,
    'vmax': loc_np.shape[0]**0.4,
}
norm = mpl.colors.Normalize(**kw)
sm = ScalarMappable(cmap=cmap)
for check_i in range(8):
    
    trj=loc_np[:,check_i,:]
    colors = [cmap(norm(i**0.4)) for i in range(trj.shape[0])]
    x,y,z=trj[:,0]*(grid_size-1),trj[:,1]*(grid_size-1),-trj[:,2]*(grid_size-1)
    segments = [list(zip(x[i:i+2], y[i:i+2], z[i:i+2])) for i in range(len(x)-1)]
    lc = Line3DCollection(segments, colors=colors,zorder=1e10)
    sc=ax1.add_collection(lc)
ax1.scatter(loc_earthquake_coord[:,0]*(grid_size-1),loc_earthquake_coord[:,1]*(grid_size-1),-loc_earthquake_coord[:,2]*(grid_size-1),s=30,color='white',marker='^',label='Earthquake',depthshade=0,edgecolors='black',zorder=1e30)
