# %%
import numpy as np
import torch
import torch.nn as nn
import torchvision
import torchvision.transforms as T
from tqdm import tqdm
import torch.nn.functional as F
from utils import greed_assignment,LAP
from plot_utils import plot_3d
from model import Siren,AssignmentModel,Autoencoder
from data_model import traveling_time_dataset,WaveSpeedDataset,get_latent
from sgld import SGLD
from ot.lp import wasserstein_1d
import matplotlib.pyplot as plt
import copy
device = torch.device('cuda:3' if torch.cuda.is_available() else 'cpu')
# %load_ext autoreload
# %autoreload 2

# %%
grid_size=32 #For larger grid_size or more modes, more training samples and multi-GPU are recommended.
vmin=0.5
vmax=2.5
n_station=20
n_wavespeed=5000
n_wavespeed_test=100
n_mode=20
density=0.15

# %% [markdown]
# ## Generate dataset

# %%
WaveSpeedData=WaveSpeedDataset(n_wavespeed,n_wavespeed_test, grid_size,n_mode,density,vmin,vmax)
torch.save(WaveSpeedData,'save/WaveSpeedData.pt')

# %%
_=plot_3d(WaveSpeedData.data_wavespeed[1],vmin=vmin*10,vmax=vmax*10)

# %% [markdown]
# # Train auto encoder

# %%
L=6 #latent dim
model_autoencoder=Autoencoder(capacity=64,latent_dims=L).to(device)
ATE_train_loader = torch.utils.data.DataLoader(WaveSpeedData, batch_size=32, shuffle=True,num_workers=8)
optimizer = torch.optim.Adam(params=model_autoencoder.parameters(), lr=1e-3)
#from lion_pytorch import Lion
#optimizer = Lion(model_autoencoder.parameters(), lr=1e-4, weight_decay=1e-2)

# %%
model_autoencoder.train()
train_loss_avg = []
num_epochs=1000
print('Training ...')
for epoch in range(num_epochs):
    train_loss_avg.append(0)
    num_batches = 0
    #for data in tqdm(ATE_train_loader):
    for data in ATE_train_loader:
        image_batch = data['image'].to(device)
        image_batch=image_batch.unsqueeze(1)
        image_batch_recon,_ = model_autoencoder(image_batch)
        loss = F.mse_loss(image_batch_recon, image_batch)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        train_loss_avg[-1] += loss.item()
        num_batches += 1
    train_loss_avg[-1] /= num_batches
    if train_loss_avg[-1]<1e-4:
        break
    if epoch%1==0:
        print('Epoch [%d / %d] average reconstruction error: %f' % (epoch+1, num_epochs, train_loss_avg[-1]))
        torch.save(model_autoencoder.state_dict(), 'save/ATE.pt')
# Out:
# Training ...
# Epoch [1 / 1000] average reconstruction error: 0.101022
# Epoch [2 / 1000] average reconstruction error: 0.043504
# Epoch [3 / 1000] average reconstruction error: 0.038012
# Epoch [4 / 1000] average reconstruction error: 0.031641
# Epoch [5 / 1000] average reconstruction error: 0.026900
# Epoch [6 / 1000] average reconstruction error: 0.024920
# Epoch [7 / 1000] average reconstruction error: 0.023997
# Epoch [8 / 1000] average reconstruction error: 0.021776
# Epoch [9 / 1000] average reconstruction error: 0.023466
# Epoch [10 / 1000] average reconstruction error: 0.021259
# Epoch [11 / 1000] average reconstruction error: 0.021094
# Epoch [12 / 1000] average reconstruction error: 0.020237
# Epoch [13 / 1000] average reconstruction error: 0.019189
# Epoch [14 / 1000] average reconstruction error: 0.019669
# Epoch [15 / 1000] average reconstruction error: 0.019724
# Epoch [16 / 1000] average reconstruction error: 0.019417
# Epoch [17 / 1000] average reconstruction error: 0.019190
# Epoch [18 / 1000] average reconstruction error: 0.018273
# Epoch [19 / 1000] average reconstruction error: 0.018046
# Epoch [20 / 1000] average reconstruction error: 0.017677
# Epoch [21 / 1000] average reconstruction error: 0.017777
# Epoch [22 / 1000] average reconstruction error: 0.017664
# Epoch [23 / 1000] average reconstruction error: 0.017596
# Epoch [24 / 1000] average reconstruction error: 0.017551
# Epoch [25 / 1000] average reconstruction error: 0.017355
# Epoch [26 / 1000] average reconstruction error: 0.017174
# Epoch [27 / 1000] average reconstruction error: 0.017032
# Epoch [28 / 1000] average reconstruction error: 0.017059
# Epoch [29 / 1000] average reconstruction error: 0.016376
# Epoch [30 / 1000] average reconstruction error: 0.016182
# Epoch [31 / 1000] average reconstruction error: 0.016240
# Epoch [32 / 1000] average reconstruction error: 0.016101
# Epoch [33 / 1000] average reconstruction error: 0.017100
# Epoch [34 / 1000] average reconstruction error: 0.016124
# Epoch [35 / 1000] average reconstruction error: 0.016177
# Epoch [36 / 1000] average reconstruction error: 0.015925
# Epoch [37 / 1000] average reconstruction error: 0.015760
# Epoch [38 / 1000] average reconstruction error: 0.015321
# Epoch [39 / 1000] average reconstruction error: 0.015223
# Epoch [40 / 1000] average reconstruction error: 0.015525
# Epoch [41 / 1000] average reconstruction error: 0.015163
# Epoch [42 / 1000] average reconstruction error: 0.014989
# Epoch [43 / 1000] average reconstruction error: 0.014868
# Epoch [44 / 1000] average reconstruction error: 0.015566
# Epoch [45 / 1000] average reconstruction error: 0.014440
# Epoch [46 / 1000] average reconstruction error: 0.015002
# Epoch [47 / 1000] average reconstruction error: 0.014997
# Epoch [48 / 1000] average reconstruction error: 0.013903
# Epoch [49 / 1000] average reconstruction error: 0.014244
# Epoch [50 / 1000] average reconstruction error: 0.014135
# Epoch [51 / 1000] average reconstruction error: 0.014572
# Epoch [52 / 1000] average reconstruction error: 0.014196
# Epoch [53 / 1000] average reconstruction error: 0.014785
# Epoch [54 / 1000] average reconstruction error: 0.013735
# Epoch [55 / 1000] average reconstruction error: 0.013811
# Epoch [56 / 1000] average reconstruction error: 0.013986
# Epoch [57 / 1000] average reconstruction error: 0.013343
# Epoch [58 / 1000] average reconstruction error: 0.013783
# Epoch [59 / 1000] average reconstruction error: 0.014508
# Epoch [60 / 1000] average reconstruction error: 0.013446
# Epoch [61 / 1000] average reconstruction error: 0.013731
# Epoch [62 / 1000] average reconstruction error: 0.013549
# Epoch [63 / 1000] average reconstruction error: 0.013360
# Epoch [64 / 1000] average reconstruction error: 0.013049
# Epoch [65 / 1000] average reconstruction error: 0.013404
# Epoch [66 / 1000] average reconstruction error: 0.013662
# Epoch [67 / 1000] average reconstruction error: 0.013531
# Epoch [68 / 1000] average reconstruction error: 0.013219
# Epoch [69 / 1000] average reconstruction error: 0.013155
# Epoch [70 / 1000] average reconstruction error: 0.012663
# Epoch [71 / 1000] average reconstruction error: 0.013218
# Epoch [72 / 1000] average reconstruction error: 0.013067
# Epoch [73 / 1000] average reconstruction error: 0.012855
# Epoch [74 / 1000] average reconstruction error: 0.012842
# Epoch [75 / 1000] average reconstruction error: 0.013478
# Epoch [76 / 1000] average reconstruction error: 0.012932
# Epoch [77 / 1000] average reconstruction error: 0.012664
# Epoch [78 / 1000] average reconstruction error: 0.012501
# Epoch [79 / 1000] average reconstruction error: 0.012615
# Epoch [80 / 1000] average reconstruction error: 0.012402
# Epoch [81 / 1000] average reconstruction error: 0.012304
# Epoch [82 / 1000] average reconstruction error: 0.012261
# Epoch [83 / 1000] average reconstruction error: 0.012266
# Epoch [84 / 1000] average reconstruction error: 0.012177
# Epoch [85 / 1000] average reconstruction error: 0.012392
# Epoch [86 / 1000] average reconstruction error: 0.012393
# Epoch [87 / 1000] average reconstruction error: 0.012307
# Epoch [88 / 1000] average reconstruction error: 0.012022
# Epoch [89 / 1000] average reconstruction error: 0.012077
# Epoch [90 / 1000] average reconstruction error: 0.012137
# Epoch [91 / 1000] average reconstruction error: 0.012038
# Epoch [92 / 1000] average reconstruction error: 0.011994
# Epoch [93 / 1000] average reconstruction error: 0.012055
# Epoch [94 / 1000] average reconstruction error: 0.011566
# Epoch [95 / 1000] average reconstruction error: 0.011706
# Epoch [96 / 1000] average reconstruction error: 0.011973
# Epoch [97 / 1000] average reconstruction error: 0.011849
# Epoch [98 / 1000] average reconstruction error: 0.011620
# Epoch [99 / 1000] average reconstruction error: 0.011983
# Epoch [100 / 1000] average reconstruction error: 0.011666
# Epoch [101 / 1000] average reconstruction error: 0.011448
# Epoch [102 / 1000] average reconstruction error: 0.011374
# Epoch [103 / 1000] average reconstruction error: 0.011666
# Epoch [104 / 1000] average reconstruction error: 0.011391
# Epoch [105 / 1000] average reconstruction error: 0.011385
# Epoch [106 / 1000] average reconstruction error: 0.011190
# Epoch [107 / 1000] average reconstruction error: 0.011171
# Epoch [108 / 1000] average reconstruction error: 0.011472
# Epoch [109 / 1000] average reconstruction error: 0.011335
# Epoch [110 / 1000] average reconstruction error: 0.011286
# Epoch [111 / 1000] average reconstruction error: 0.012023
# Epoch [112 / 1000] average reconstruction error: 0.011279
# Epoch [113 / 1000] average reconstruction error: 0.011425
# Epoch [114 / 1000] average reconstruction error: 0.011278
# Epoch [115 / 1000] average reconstruction error: 0.010709
# Epoch [116 / 1000] average reconstruction error: 0.010779
# Epoch [117 / 1000] average reconstruction error: 0.010739
# Epoch [118 / 1000] average reconstruction error: 0.011193
# Epoch [119 / 1000] average reconstruction error: 0.010969
# Epoch [120 / 1000] average reconstruction error: 0.011176
# Epoch [121 / 1000] average reconstruction error: 0.011575
# Epoch [122 / 1000] average reconstruction error: 0.010796
# Epoch [123 / 1000] average reconstruction error: 0.011218
# Epoch [124 / 1000] average reconstruction error: 0.011525
# Epoch [125 / 1000] average reconstruction error: 0.010705
# Epoch [126 / 1000] average reconstruction error: 0.010677
# Epoch [127 / 1000] average reconstruction error: 0.010712
# Epoch [128 / 1000] average reconstruction error: 0.010908
# Epoch [129 / 1000] average reconstruction error: 0.010996
# Epoch [130 / 1000] average reconstruction error: 0.010901
# Epoch [131 / 1000] average reconstruction error: 0.010324
# Epoch [132 / 1000] average reconstruction error: 0.010702
# Epoch [133 / 1000] average reconstruction error: 0.010272
# Epoch [134 / 1000] average reconstruction error: 0.010163
# Epoch [135 / 1000] average reconstruction error: 0.010330
# Epoch [136 / 1000] average reconstruction error: 0.010268
# Epoch [137 / 1000] average reconstruction error: 0.010584
# Epoch [138 / 1000] average reconstruction error: 0.010271
# Epoch [139 / 1000] average reconstruction error: 0.010232
# Epoch [140 / 1000] average reconstruction error: 0.010422
# Epoch [141 / 1000] average reconstruction error: 0.010889
# Epoch [142 / 1000] average reconstruction error: 0.010410
# Epoch [143 / 1000] average reconstruction error: 0.010002
# Epoch [144 / 1000] average reconstruction error: 0.009933
# Epoch [145 / 1000] average reconstruction error: 0.010264
# Epoch [146 / 1000] average reconstruction error: 0.010223
# Epoch [147 / 1000] average reconstruction error: 0.010161
# Epoch [148 / 1000] average reconstruction error: 0.010400
# Epoch [149 / 1000] average reconstruction error: 0.009723
# Epoch [150 / 1000] average reconstruction error: 0.010217
# Epoch [151 / 1000] average reconstruction error: 0.010332
# Epoch [152 / 1000] average reconstruction error: 0.010153
# Epoch [153 / 1000] average reconstruction error: 0.010225
# Epoch [154 / 1000] average reconstruction error: 0.009826
# Epoch [155 / 1000] average reconstruction error: 0.010046
# Epoch [156 / 1000] average reconstruction error: 0.010211
# Epoch [157 / 1000] average reconstruction error: 0.010359
# Epoch [158 / 1000] average reconstruction error: 0.010050
# Epoch [159 / 1000] average reconstruction error: 0.009855
# Epoch [160 / 1000] average reconstruction error: 0.010140
# Epoch [161 / 1000] average reconstruction error: 0.009712
# Epoch [162 / 1000] average reconstruction error: 0.009923
# Epoch [163 / 1000] average reconstruction error: 0.010253
# Epoch [164 / 1000] average reconstruction error: 0.009919
# Epoch [165 / 1000] average reconstruction error: 0.009802
# Epoch [166 / 1000] average reconstruction error: 0.009722
# Epoch [167 / 1000] average reconstruction error: 0.009692
# Epoch [168 / 1000] average reconstruction error: 0.009430
# Epoch [169 / 1000] average reconstruction error: 0.009609
# Epoch [170 / 1000] average reconstruction error: 0.009731
# Epoch [171 / 1000] average reconstruction error: 0.010011
# Epoch [172 / 1000] average reconstruction error: 0.009777
# Epoch [173 / 1000] average reconstruction error: 0.009866
# Epoch [174 / 1000] average reconstruction error: 0.009629
# Epoch [175 / 1000] average reconstruction error: 0.009478
# Epoch [176 / 1000] average reconstruction error: 0.009030
# Epoch [177 / 1000] average reconstruction error: 0.009284
# Epoch [178 / 1000] average reconstruction error: 0.009157
# Epoch [179 / 1000] average reconstruction error: 0.009566
# Epoch [180 / 1000] average reconstruction error: 0.009547
# Epoch [181 / 1000] average reconstruction error: 0.009429
# Epoch [182 / 1000] average reconstruction error: 0.009157
# Epoch [183 / 1000] average reconstruction error: 0.009461
# Epoch [184 / 1000] average reconstruction error: 0.009327
# Epoch [185 / 1000] average reconstruction error: 0.009084
# Epoch [186 / 1000] average reconstruction error: 0.009343
# Epoch [187 / 1000] average reconstruction error: 0.009175
# Epoch [188 / 1000] average reconstruction error: 0.008874
# Epoch [189 / 1000] average reconstruction error: 0.009375
# Epoch [190 / 1000] average reconstruction error: 0.009265
# Epoch [191 / 1000] average reconstruction error: 0.009470
# Epoch [192 / 1000] average reconstruction error: 0.009172
# Epoch [193 / 1000] average reconstruction error: 0.009513
# Epoch [194 / 1000] average reconstruction error: 0.009739
# Epoch [195 / 1000] average reconstruction error: 0.009287
# Epoch [196 / 1000] average reconstruction error: 0.009165
# Epoch [197 / 1000] average reconstruction error: 0.009447
# Epoch [198 / 1000] average reconstruction error: 0.008886
# Epoch [199 / 1000] average reconstruction error: 0.009250
# Epoch [200 / 1000] average reconstruction error: 0.009535
# Epoch [201 / 1000] average reconstruction error: 0.009566
# Epoch [202 / 1000] average reconstruction error: 0.009051
# Epoch [203 / 1000] average reconstruction error: 0.008945
# Epoch [204 / 1000] average reconstruction error: 0.008970
# Epoch [205 / 1000] average reconstruction error: 0.009067
# Epoch [206 / 1000] average reconstruction error: 0.009244
# Epoch [207 / 1000] average reconstruction error: 0.010004
# Epoch [208 / 1000] average reconstruction error: 0.009149
# Epoch [209 / 1000] average reconstruction error: 0.009089
# Epoch [210 / 1000] average reconstruction error: 0.009044
# Epoch [211 / 1000] average reconstruction error: 0.009046
# Epoch [212 / 1000] average reconstruction error: 0.009114
# Epoch [213 / 1000] average reconstruction error: 0.009128
# Epoch [214 / 1000] average reconstruction error: 0.009070
# Epoch [215 / 1000] average reconstruction error: 0.009073
# Epoch [216 / 1000] average reconstruction error: 0.008976
# Epoch [217 / 1000] average reconstruction error: 0.008766
# Epoch [218 / 1000] average reconstruction error: 0.008729
# Epoch [219 / 1000] average reconstruction error: 0.008648
# Epoch [220 / 1000] average reconstruction error: 0.009257
# Epoch [221 / 1000] average reconstruction error: 0.008927
# Epoch [222 / 1000] average reconstruction error: 0.008895
# Epoch [223 / 1000] average reconstruction error: 0.008850
# Epoch [224 / 1000] average reconstruction error: 0.008764
# Epoch [225 / 1000] average reconstruction error: 0.008767
# Epoch [226 / 1000] average reconstruction error: 0.008760
# Epoch [227 / 1000] average reconstruction error: 0.009349
# Epoch [228 / 1000] average reconstruction error: 0.008766
# Epoch [229 / 1000] average reconstruction error: 0.008543
# Epoch [230 / 1000] average reconstruction error: 0.008314
# Epoch [231 / 1000] average reconstruction error: 0.008669
# Epoch [232 / 1000] average reconstruction error: 0.009008
# Epoch [233 / 1000] average reconstruction error: 0.009612
# Epoch [234 / 1000] average reconstruction error: 0.008715
# Epoch [235 / 1000] average reconstruction error: 0.008618
# Epoch [236 / 1000] average reconstruction error: 0.008427
# Epoch [237 / 1000] average reconstruction error: 0.008408
# Epoch [238 / 1000] average reconstruction error: 0.008496
# Epoch [239 / 1000] average reconstruction error: 0.008321
# Epoch [240 / 1000] average reconstruction error: 0.008664
# Epoch [241 / 1000] average reconstruction error: 0.009017
# Epoch [242 / 1000] average reconstruction error: 0.008558
# Epoch [243 / 1000] average reconstruction error: 0.008761
# Epoch [244 / 1000] average reconstruction error: 0.009157
# Epoch [245 / 1000] average reconstruction error: 0.009541
# Epoch [246 / 1000] average reconstruction error: 0.008617
# Epoch [247 / 1000] average reconstruction error: 0.008432
# Epoch [248 / 1000] average reconstruction error: 0.008485
# Epoch [249 / 1000] average reconstruction error: 0.008316
# Epoch [250 / 1000] average reconstruction error: 0.008446
# Epoch [251 / 1000] average reconstruction error: 0.008429
# Epoch [252 / 1000] average reconstruction error: 0.008597
# Epoch [253 / 1000] average reconstruction error: 0.008526
# Epoch [254 / 1000] average reconstruction error: 0.008623
# Epoch [255 / 1000] average reconstruction error: 0.008378
# Epoch [256 / 1000] average reconstruction error: 0.008245
# Epoch [257 / 1000] average reconstruction error: 0.008192
# Epoch [258 / 1000] average reconstruction error: 0.008542
# Epoch [259 / 1000] average reconstruction error: 0.008815
# Epoch [260 / 1000] average reconstruction error: 0.008182
# Epoch [261 / 1000] average reconstruction error: 0.008346
# Epoch [262 / 1000] average reconstruction error: 0.008173
# Epoch [263 / 1000] average reconstruction error: 0.008131
# Epoch [264 / 1000] average reconstruction error: 0.008490
# Epoch [265 / 1000] average reconstruction error: 0.008632
# Epoch [266 / 1000] average reconstruction error: 0.008131
# Epoch [267 / 1000] average reconstruction error: 0.008183
# Epoch [268 / 1000] average reconstruction error: 0.008414
# Epoch [269 / 1000] average reconstruction error: 0.008381
# Epoch [270 / 1000] average reconstruction error: 0.008325
# Epoch [271 / 1000] average reconstruction error: 0.008228
# Epoch [272 / 1000] average reconstruction error: 0.008472
# Epoch [273 / 1000] average reconstruction error: 0.008043
# Epoch [274 / 1000] average reconstruction error: 0.008201
# Epoch [275 / 1000] average reconstruction error: 0.008137
# Epoch [276 / 1000] average reconstruction error: 0.008492
# Epoch [277 / 1000] average reconstruction error: 0.008679
# Epoch [278 / 1000] average reconstruction error: 0.008205
# Epoch [279 / 1000] average reconstruction error: 0.008226
# Epoch [280 / 1000] average reconstruction error: 0.008801
# Epoch [281 / 1000] average reconstruction error: 0.008108
# Epoch [282 / 1000] average reconstruction error: 0.008502
# Epoch [283 / 1000] average reconstruction error: 0.008154
# Epoch [284 / 1000] average reconstruction error: 0.008191
# Epoch [285 / 1000] average reconstruction error: 0.008316
# Epoch [286 / 1000] average reconstruction error: 0.008145
# Epoch [287 / 1000] average reconstruction error: 0.008505
# Epoch [288 / 1000] average reconstruction error: 0.008099
# Epoch [289 / 1000] average reconstruction error: 0.008271
# Epoch [290 / 1000] average reconstruction error: 0.008088
# Epoch [291 / 1000] average reconstruction error: 0.008263
# Epoch [292 / 1000] average reconstruction error: 0.008339
# Epoch [293 / 1000] average reconstruction error: 0.008111
# Epoch [294 / 1000] average reconstruction error: 0.008034
# Epoch [295 / 1000] average reconstruction error: 0.008334
# Epoch [296 / 1000] average reconstruction error: 0.008093
# Epoch [297 / 1000] average reconstruction error: 0.008139
# Epoch [298 / 1000] average reconstruction error: 0.008474
# Epoch [299 / 1000] average reconstruction error: 0.007831
# Epoch [300 / 1000] average reconstruction error: 0.007971
# Epoch [301 / 1000] average reconstruction error: 0.008012
# Epoch [302 / 1000] average reconstruction error: 0.007983
# Epoch [303 / 1000] average reconstruction error: 0.007684
# Epoch [304 / 1000] average reconstruction error: 0.007834
# Epoch [305 / 1000] average reconstruction error: 0.007834
# Epoch [306 / 1000] average reconstruction error: 0.007710
# Epoch [307 / 1000] average reconstruction error: 0.008052
# Epoch [308 / 1000] average reconstruction error: 0.007997
# Epoch [309 / 1000] average reconstruction error: 0.007919
# Epoch [310 / 1000] average reconstruction error: 0.007716
# Epoch [311 / 1000] average reconstruction error: 0.007973
# Epoch [312 / 1000] average reconstruction error: 0.007733
# Epoch [313 / 1000] average reconstruction error: 0.008095
# Epoch [314 / 1000] average reconstruction error: 0.008076
# Epoch [315 / 1000] average reconstruction error: 0.008029
# Epoch [316 / 1000] average reconstruction error: 0.007942
# Epoch [317 / 1000] average reconstruction error: 0.008069
# Epoch [318 / 1000] average reconstruction error: 0.007896
# Epoch [319 / 1000] average reconstruction error: 0.007994
# Epoch [320 / 1000] average reconstruction error: 0.008600
# Epoch [321 / 1000] average reconstruction error: 0.009216
# Epoch [322 / 1000] average reconstruction error: 0.008033
# Epoch [323 / 1000] average reconstruction error: 0.007649
# Epoch [324 / 1000] average reconstruction error: 0.007727
# Epoch [325 / 1000] average reconstruction error: 0.007767
# Epoch [326 / 1000] average reconstruction error: 0.007536
# Epoch [327 / 1000] average reconstruction error: 0.007401
# Epoch [328 / 1000] average reconstruction error: 0.007749
# Epoch [329 / 1000] average reconstruction error: 0.007902
# Epoch [330 / 1000] average reconstruction error: 0.007472
# Epoch [331 / 1000] average reconstruction error: 0.007911
# Epoch [332 / 1000] average reconstruction error: 0.007729
# Epoch [333 / 1000] average reconstruction error: 0.007457
# Epoch [334 / 1000] average reconstruction error: 0.007858
# Epoch [335 / 1000] average reconstruction error: 0.007539
# Epoch [336 / 1000] average reconstruction error: 0.007769
# Epoch [337 / 1000] average reconstruction error: 0.007943
# Epoch [338 / 1000] average reconstruction error: 0.008546
# Epoch [339 / 1000] average reconstruction error: 0.007439
# Epoch [340 / 1000] average reconstruction error: 0.007729
# Epoch [341 / 1000] average reconstruction error: 0.007608
# Epoch [342 / 1000] average reconstruction error: 0.007738
# Epoch [343 / 1000] average reconstruction error: 0.007423
# Epoch [344 / 1000] average reconstruction error: 0.007449
# Epoch [345 / 1000] average reconstruction error: 0.007583
# Epoch [346 / 1000] average reconstruction error: 0.007955
# Epoch [347 / 1000] average reconstruction error: 0.007398
# Epoch [348 / 1000] average reconstruction error: 0.007574
# Epoch [349 / 1000] average reconstruction error: 0.007473
# Epoch [350 / 1000] average reconstruction error: 0.007376
# Epoch [351 / 1000] average reconstruction error: 0.007521
# Epoch [352 / 1000] average reconstruction error: 0.007824
# Epoch [353 / 1000] average reconstruction error: 0.007805
# Epoch [354 / 1000] average reconstruction error: 0.007577
# Epoch [355 / 1000] average reconstruction error: 0.007453
# Epoch [356 / 1000] average reconstruction error: 0.007530
# Epoch [357 / 1000] average reconstruction error: 0.007718
# Epoch [358 / 1000] average reconstruction error: 0.007680
# Epoch [359 / 1000] average reconstruction error: 0.007506
# Epoch [360 / 1000] average reconstruction error: 0.007450
# Epoch [361 / 1000] average reconstruction error: 0.007460
# Epoch [362 / 1000] average reconstruction error: 0.007728
# Epoch [363 / 1000] average reconstruction error: 0.007695
# Epoch [364 / 1000] average reconstruction error: 0.007465
# Epoch [365 / 1000] average reconstruction error: 0.007356
# Epoch [366 / 1000] average reconstruction error: 0.007367
# Epoch [367 / 1000] average reconstruction error: 0.007663
# Epoch [368 / 1000] average reconstruction error: 0.007774
# Epoch [369 / 1000] average reconstruction error: 0.007336
# Epoch [370 / 1000] average reconstruction error: 0.007458
# Epoch [371 / 1000] average reconstruction error: 0.007740
# Epoch [372 / 1000] average reconstruction error: 0.007689
# Epoch [373 / 1000] average reconstruction error: 0.007343
# Epoch [374 / 1000] average reconstruction error: 0.007648
# Epoch [375 / 1000] average reconstruction error: 0.007404
# Epoch [376 / 1000] average reconstruction error: 0.007447
# Epoch [377 / 1000] average reconstruction error: 0.007442
# Epoch [378 / 1000] average reconstruction error: 0.007829
# Epoch [379 / 1000] average reconstruction error: 0.007797
# Epoch [380 / 1000] average reconstruction error: 0.007428
# Epoch [381 / 1000] average reconstruction error: 0.007314
# Epoch [382 / 1000] average reconstruction error: 0.007179
# Epoch [383 / 1000] average reconstruction error: 0.007410
# Epoch [384 / 1000] average reconstruction error: 0.007140
# Epoch [385 / 1000] average reconstruction error: 0.007249
# Epoch [386 / 1000] average reconstruction error: 0.007438
# Epoch [387 / 1000] average reconstruction error: 0.007535
# Epoch [388 / 1000] average reconstruction error: 0.007673
# Epoch [389 / 1000] average reconstruction error: 0.007382
# Epoch [390 / 1000] average reconstruction error: 0.007060
# Epoch [391 / 1000] average reconstruction error: 0.007269
# Epoch [392 / 1000] average reconstruction error: 0.007129
# Epoch [393 / 1000] average reconstruction error: 0.007224
# Epoch [394 / 1000] average reconstruction error: 0.007614
# Epoch [395 / 1000] average reconstruction error: 0.007651
# Epoch [396 / 1000] average reconstruction error: 0.007263
# Epoch [397 / 1000] average reconstruction error: 0.007318
# Epoch [398 / 1000] average reconstruction error: 0.007212
# Epoch [399 / 1000] average reconstruction error: 0.007153
# Epoch [400 / 1000] average reconstruction error: 0.007211
# Epoch [401 / 1000] average reconstruction error: 0.007549
# Epoch [402 / 1000] average reconstruction error: 0.007479
# Epoch [403 / 1000] average reconstruction error: 0.007357
# Epoch [404 / 1000] average reconstruction error: 0.007069
# Epoch [405 / 1000] average reconstruction error: 0.007134
# Epoch [406 / 1000] average reconstruction error: 0.007528
# Epoch [407 / 1000] average reconstruction error: 0.008590
# Epoch [408 / 1000] average reconstruction error: 0.007586
# Epoch [409 / 1000] average reconstruction error: 0.007248
# Epoch [410 / 1000] average reconstruction error: 0.007128
# Epoch [411 / 1000] average reconstruction error: 0.007252
# Epoch [412 / 1000] average reconstruction error: 0.007068
# Epoch [413 / 1000] average reconstruction error: 0.007161
# Epoch [414 / 1000] average reconstruction error: 0.007357
# Epoch [415 / 1000] average reconstruction error: 0.007391
# Epoch [416 / 1000] average reconstruction error: 0.006953
# Epoch [417 / 1000] average reconstruction error: 0.007094
# Epoch [418 / 1000] average reconstruction error: 0.007631
# Epoch [419 / 1000] average reconstruction error: 0.007689
# Epoch [420 / 1000] average reconstruction error: 0.007120
# Epoch [421 / 1000] average reconstruction error: 0.006949
# Epoch [422 / 1000] average reconstruction error: 0.007022
# Epoch [423 / 1000] average reconstruction error: 0.006936
# Epoch [424 / 1000] average reconstruction error: 0.007049
# Epoch [425 / 1000] average reconstruction error: 0.007300
# Epoch [426 / 1000] average reconstruction error: 0.007538
# Epoch [427 / 1000] average reconstruction error: 0.007319
# Epoch [428 / 1000] average reconstruction error: 0.007142
# Epoch [429 / 1000] average reconstruction error: 0.007222
# Epoch [430 / 1000] average reconstruction error: 0.007942
# Epoch [431 / 1000] average reconstruction error: 0.008973
# Epoch [432 / 1000] average reconstruction error: 0.007452
# Epoch [433 / 1000] average reconstruction error: 0.007047
# Epoch [434 / 1000] average reconstruction error: 0.007163
# Epoch [435 / 1000] average reconstruction error: 0.007168
# Epoch [436 / 1000] average reconstruction error: 0.007363
# Epoch [437 / 1000] average reconstruction error: 0.006985
# Epoch [438 / 1000] average reconstruction error: 0.007207
# Epoch [439 / 1000] average reconstruction error: 0.007387
# Epoch [440 / 1000] average reconstruction error: 0.007020
# Epoch [441 / 1000] average reconstruction error: 0.006784
# Epoch [442 / 1000] average reconstruction error: 0.007387
# Epoch [443 / 1000] average reconstruction error: 0.007274
# Epoch [444 / 1000] average reconstruction error: 0.007011
# Epoch [445 / 1000] average reconstruction error: 0.007024
# Epoch [446 / 1000] average reconstruction error: 0.007010
# Epoch [447 / 1000] average reconstruction error: 0.006994
# Epoch [448 / 1000] average reconstruction error: 0.007751
# Epoch [449 / 1000] average reconstruction error: 0.008205
# Epoch [450 / 1000] average reconstruction error: 0.007456
# Epoch [451 / 1000] average reconstruction error: 0.007179
# Epoch [452 / 1000] average reconstruction error: 0.007138
# Epoch [453 / 1000] average reconstruction error: 0.007345
# Epoch [454 / 1000] average reconstruction error: 0.007067
# Epoch [455 / 1000] average reconstruction error: 0.007009
# Epoch [456 / 1000] average reconstruction error: 0.007112
# Epoch [457 / 1000] average reconstruction error: 0.007396
# Epoch [458 / 1000] average reconstruction error: 0.007327
# Epoch [459 / 1000] average reconstruction error: 0.006959
# Epoch [460 / 1000] average reconstruction error: 0.007691
# Epoch [461 / 1000] average reconstruction error: 0.007446
# Epoch [462 / 1000] average reconstruction error: 0.007231
# Epoch [463 / 1000] average reconstruction error: 0.006909
# Epoch [464 / 1000] average reconstruction error: 0.006905
# Epoch [465 / 1000] average reconstruction error: 0.007047
# Epoch [466 / 1000] average reconstruction error: 0.006657
# Epoch [467 / 1000] average reconstruction error: 0.007021
# Epoch [468 / 1000] average reconstruction error: 0.006878
# Epoch [469 / 1000] average reconstruction error: 0.006907
# Epoch [470 / 1000] average reconstruction error: 0.006824
# Epoch [471 / 1000] average reconstruction error: 0.007149
# Epoch [472 / 1000] average reconstruction error: 0.007246
# Epoch [473 / 1000] average reconstruction error: 0.006966
# Epoch [474 / 1000] average reconstruction error: 0.007109
# Epoch [475 / 1000] average reconstruction error: 0.007027
# Epoch [476 / 1000] average reconstruction error: 0.006793
# Epoch [477 / 1000] average reconstruction error: 0.006815
# Epoch [478 / 1000] average reconstruction error: 0.007048
# Epoch [479 / 1000] average reconstruction error: 0.007196
# Epoch [480 / 1000] average reconstruction error: 0.006972
# Epoch [481 / 1000] average reconstruction error: 0.007082
# Epoch [482 / 1000] average reconstruction error: 0.007160
# Epoch [483 / 1000] average reconstruction error: 0.006699
# Epoch [484 / 1000] average reconstruction error: 0.006557
# Epoch [485 / 1000] average reconstruction error: 0.006876
# Epoch [486 / 1000] average reconstruction error: 0.007063
# Epoch [487 / 1000] average reconstruction error: 0.007086
# Epoch [488 / 1000] average reconstruction error: 0.006797
# Epoch [489 / 1000] average reconstruction error: 0.006777
# Epoch [490 / 1000] average reconstruction error: 0.007041
# Epoch [491 / 1000] average reconstruction error: 0.007064
# Epoch [492 / 1000] average reconstruction error: 0.006890
# Epoch [493 / 1000] average reconstruction error: 0.007251
# Epoch [494 / 1000] average reconstruction error: 0.006946
# Epoch [495 / 1000] average reconstruction error: 0.007104
# Epoch [496 / 1000] average reconstruction error: 0.007102
# Epoch [497 / 1000] average reconstruction error: 0.007256
# Epoch [498 / 1000] average reconstruction error: 0.007002
# Epoch [499 / 1000] average reconstruction error: 0.006649
# Epoch [500 / 1000] average reconstruction error: 0.007233
# Epoch [501 / 1000] average reconstruction error: 0.007082
# Epoch [502 / 1000] average reconstruction error: 0.006929
# Epoch [503 / 1000] average reconstruction error: 0.006778
# Epoch [504 / 1000] average reconstruction error: 0.006754
# Epoch [505 / 1000] average reconstruction error: 0.006788
# Epoch [506 / 1000] average reconstruction error: 0.006713
# Epoch [507 / 1000] average reconstruction error: 0.006662
# Epoch [508 / 1000] average reconstruction error: 0.006674
# Epoch [509 / 1000] average reconstruction error: 0.006636
# Epoch [510 / 1000] average reconstruction error: 0.006378
# Epoch [511 / 1000] average reconstruction error: 0.006876
# Epoch [512 / 1000] average reconstruction error: 0.006399
# Epoch [513 / 1000] average reconstruction error: 0.006592
# Epoch [514 / 1000] average reconstruction error: 0.006439
# Epoch [515 / 1000] average reconstruction error: 0.006623
# Epoch [516 / 1000] average reconstruction error: 0.007046
# Epoch [517 / 1000] average reconstruction error: 0.006947
# Epoch [518 / 1000] average reconstruction error: 0.006760
# Epoch [519 / 1000] average reconstruction error: 0.006697
# Epoch [520 / 1000] average reconstruction error: 0.006746
# Epoch [521 / 1000] average reconstruction error: 0.006600
# Epoch [522 / 1000] average reconstruction error: 0.006519
# Epoch [523 / 1000] average reconstruction error: 0.006936
# Epoch [524 / 1000] average reconstruction error: 0.006804
# Epoch [525 / 1000] average reconstruction error: 0.006631
# Epoch [526 / 1000] average reconstruction error: 0.006644
# Epoch [527 / 1000] average reconstruction error: 0.006511
# Epoch [528 / 1000] average reconstruction error: 0.006570
# Epoch [529 / 1000] average reconstruction error: 0.006680
# Epoch [530 / 1000] average reconstruction error: 0.006655
# Epoch [531 / 1000] average reconstruction error: 0.006800
# Epoch [532 / 1000] average reconstruction error: 0.006898
# Epoch [533 / 1000] average reconstruction error: 0.006565
# Epoch [534 / 1000] average reconstruction error: 0.006472
# Epoch [535 / 1000] average reconstruction error: 0.006514
# Epoch [536 / 1000] average reconstruction error: 0.007614
# Epoch [537 / 1000] average reconstruction error: 0.008088
# Epoch [538 / 1000] average reconstruction error: 0.006566
# Epoch [539 / 1000] average reconstruction error: 0.006637
# Epoch [540 / 1000] average reconstruction error: 0.006678
# Epoch [541 / 1000] average reconstruction error: 0.006767
# Epoch [542 / 1000] average reconstruction error: 0.006796
# Epoch [543 / 1000] average reconstruction error: 0.006694
# Epoch [544 / 1000] average reconstruction error: 0.006693
# Epoch [545 / 1000] average reconstruction error: 0.006797
# Epoch [546 / 1000] average reconstruction error: 0.006585
# Epoch [547 / 1000] average reconstruction error: 0.006806
# Epoch [548 / 1000] average reconstruction error: 0.006680
# Epoch [549 / 1000] average reconstruction error: 0.007231
# Epoch [550 / 1000] average reconstruction error: 0.007215
# Epoch [551 / 1000] average reconstruction error: 0.006780
# Epoch [552 / 1000] average reconstruction error: 0.006361
# Epoch [553 / 1000] average reconstruction error: 0.006386
# Epoch [554 / 1000] average reconstruction error: 0.006778
# Epoch [555 / 1000] average reconstruction error: 0.006450
# Epoch [556 / 1000] average reconstruction error: 0.006639
# Epoch [557 / 1000] average reconstruction error: 0.006680
# Epoch [558 / 1000] average reconstruction error: 0.006634
# Epoch [559 / 1000] average reconstruction error: 0.006512
# Epoch [560 / 1000] average reconstruction error: 0.006558
# Epoch [561 / 1000] average reconstruction error: 0.006795
# Epoch [562 / 1000] average reconstruction error: 0.006626
# Epoch [563 / 1000] average reconstruction error: 0.006490
# Epoch [564 / 1000] average reconstruction error: 0.006697
# Epoch [565 / 1000] average reconstruction error: 0.006763
# Epoch [566 / 1000] average reconstruction error: 0.006751
# Epoch [567 / 1000] average reconstruction error: 0.006698
# Epoch [568 / 1000] average reconstruction error: 0.006675
# Epoch [569 / 1000] average reconstruction error: 0.006621
# Epoch [570 / 1000] average reconstruction error: 0.006564
# Epoch [571 / 1000] average reconstruction error: 0.006405
# Epoch [572 / 1000] average reconstruction error: 0.006940
# Epoch [573 / 1000] average reconstruction error: 0.006906
# Epoch [574 / 1000] average reconstruction error: 0.006656
# Epoch [575 / 1000] average reconstruction error: 0.006718
# Epoch [576 / 1000] average reconstruction error: 0.006559
# Epoch [577 / 1000] average reconstruction error: 0.006589
# Epoch [578 / 1000] average reconstruction error: 0.007011
# Epoch [579 / 1000] average reconstruction error: 0.006884
# Epoch [580 / 1000] average reconstruction error: 0.006300
# Epoch [581 / 1000] average reconstruction error: 0.006958
# Epoch [582 / 1000] average reconstruction error: 0.006966
# Epoch [583 / 1000] average reconstruction error: 0.006652
# Epoch [584 / 1000] average reconstruction error: 0.006441
# Epoch [585 / 1000] average reconstruction error: 0.006251
# Epoch [586 / 1000] average reconstruction error: 0.006506
# Epoch [587 / 1000] average reconstruction error: 0.006968
# Epoch [588 / 1000] average reconstruction error: 0.006547
# Epoch [589 / 1000] average reconstruction error: 0.006542
# Epoch [590 / 1000] average reconstruction error: 0.006596
# Epoch [591 / 1000] average reconstruction error: 0.006359
# Epoch [592 / 1000] average reconstruction error: 0.006096
# Epoch [593 / 1000] average reconstruction error: 0.006430
# Epoch [594 / 1000] average reconstruction error: 0.006588
# Epoch [595 / 1000] average reconstruction error: 0.007014
# Epoch [596 / 1000] average reconstruction error: 0.007186
# Epoch [597 / 1000] average reconstruction error: 0.006372
# Epoch [598 / 1000] average reconstruction error: 0.006537
# Epoch [599 / 1000] average reconstruction error: 0.006348
# Epoch [600 / 1000] average reconstruction error: 0.006181
# Epoch [601 / 1000] average reconstruction error: 0.006429
# Epoch [602 / 1000] average reconstruction error: 0.006621
# Epoch [603 / 1000] average reconstruction error: 0.006474
# Epoch [604 / 1000] average reconstruction error: 0.006537
# Epoch [605 / 1000] average reconstruction error: 0.006898
# Epoch [606 / 1000] average reconstruction error: 0.007106
# Epoch [607 / 1000] average reconstruction error: 0.006479
# Epoch [608 / 1000] average reconstruction error: 0.006580
# Epoch [609 / 1000] average reconstruction error: 0.006583
# Epoch [610 / 1000] average reconstruction error: 0.006459
# Epoch [611 / 1000] average reconstruction error: 0.006508
# Epoch [612 / 1000] average reconstruction error: 0.006476
# Epoch [613 / 1000] average reconstruction error: 0.006111
# Epoch [614 / 1000] average reconstruction error: 0.006617
# Epoch [615 / 1000] average reconstruction error: 0.006715
# Epoch [616 / 1000] average reconstruction error: 0.006428
# Epoch [617 / 1000] average reconstruction error: 0.006481
# Epoch [618 / 1000] average reconstruction error: 0.006429
# Epoch [619 / 1000] average reconstruction error: 0.007136
# Epoch [620 / 1000] average reconstruction error: 0.006370
# Epoch [621 / 1000] average reconstruction error: 0.006857
# Epoch [622 / 1000] average reconstruction error: 0.007264
# Epoch [623 / 1000] average reconstruction error: 0.007606
# Epoch [624 / 1000] average reconstruction error: 0.006982
# Epoch [625 / 1000] average reconstruction error: 0.006342
# Epoch [626 / 1000] average reconstruction error: 0.006411
# Epoch [627 / 1000] average reconstruction error: 0.006629
# Epoch [628 / 1000] average reconstruction error: 0.006506
# Epoch [629 / 1000] average reconstruction error: 0.006184
# Epoch [630 / 1000] average reconstruction error: 0.005996
# Epoch [631 / 1000] average reconstruction error: 0.006595
# Epoch [632 / 1000] average reconstruction error: 0.006297
# Epoch [633 / 1000] average reconstruction error: 0.006562
# Epoch [634 / 1000] average reconstruction error: 0.006498
# Epoch [635 / 1000] average reconstruction error: 0.006490
# Epoch [636 / 1000] average reconstruction error: 0.006668
# Epoch [637 / 1000] average reconstruction error: 0.006410
# Epoch [638 / 1000] average reconstruction error: 0.006221
# Epoch [639 / 1000] average reconstruction error: 0.006104
# Epoch [640 / 1000] average reconstruction error: 0.006450
# Epoch [641 / 1000] average reconstruction error: 0.006444
# Epoch [642 / 1000] average reconstruction error: 0.006287
# Epoch [643 / 1000] average reconstruction error: 0.006136
# Epoch [644 / 1000] average reconstruction error: 0.006293
# Epoch [645 / 1000] average reconstruction error: 0.006550
# Epoch [646 / 1000] average reconstruction error: 0.006353
# Epoch [647 / 1000] average reconstruction error: 0.006140
# Epoch [648 / 1000] average reconstruction error: 0.006145
# Epoch [649 / 1000] average reconstruction error: 0.006464
# Epoch [650 / 1000] average reconstruction error: 0.006535
# Epoch [651 / 1000] average reconstruction error: 0.006311
# Epoch [652 / 1000] average reconstruction error: 0.006048
# Epoch [653 / 1000] average reconstruction error: 0.007674
# Epoch [654 / 1000] average reconstruction error: 0.007623
# Epoch [655 / 1000] average reconstruction error: 0.006319
# Epoch [656 / 1000] average reconstruction error: 0.006446
# Epoch [657 / 1000] average reconstruction error: 0.006446
# Epoch [658 / 1000] average reconstruction error: 0.006425
# Epoch [659 / 1000] average reconstruction error: 0.006509
# Epoch [660 / 1000] average reconstruction error: 0.006469
# Epoch [661 / 1000] average reconstruction error: 0.006494
# Epoch [662 / 1000] average reconstruction error: 0.006133
# Epoch [663 / 1000] average reconstruction error: 0.006232
# Epoch [664 / 1000] average reconstruction error: 0.006062
# Epoch [665 / 1000] average reconstruction error: 0.006129
# Epoch [666 / 1000] average reconstruction error: 0.006125
# Epoch [667 / 1000] average reconstruction error: 0.006142
# Epoch [668 / 1000] average reconstruction error: 0.006133
# Epoch [669 / 1000] average reconstruction error: 0.006240
# Epoch [670 / 1000] average reconstruction error: 0.006491
# Epoch [671 / 1000] average reconstruction error: 0.006297
# Epoch [672 / 1000] average reconstruction error: 0.006230
# Epoch [673 / 1000] average reconstruction error: 0.006273
# Epoch [674 / 1000] average reconstruction error: 0.006340
# Epoch [675 / 1000] average reconstruction error: 0.006126
# Epoch [676 / 1000] average reconstruction error: 0.006101
# Epoch [677 / 1000] average reconstruction error: 0.006247
# Epoch [678 / 1000] average reconstruction error: 0.006315
# Epoch [679 / 1000] average reconstruction error: 0.006203
# Epoch [680 / 1000] average reconstruction error: 0.006804
# Epoch [681 / 1000] average reconstruction error: 0.006473
# Epoch [682 / 1000] average reconstruction error: 0.006328
# Epoch [683 / 1000] average reconstruction error: 0.006547
# Epoch [684 / 1000] average reconstruction error: 0.006432
# Epoch [685 / 1000] average reconstruction error: 0.006248
# Epoch [686 / 1000] average reconstruction error: 0.006138
# Epoch [687 / 1000] average reconstruction error: 0.006434
# Epoch [688 / 1000] average reconstruction error: 0.005970
# Epoch [689 / 1000] average reconstruction error: 0.006335
# Epoch [690 / 1000] average reconstruction error: 0.006448
# Epoch [691 / 1000] average reconstruction error: 0.006532
# Epoch [692 / 1000] average reconstruction error: 0.006159
# Epoch [693 / 1000] average reconstruction error: 0.005904
# Epoch [694 / 1000] average reconstruction error: 0.006403
# Epoch [695 / 1000] average reconstruction error: 0.006171
# Epoch [696 / 1000] average reconstruction error: 0.006197
# Epoch [697 / 1000] average reconstruction error: 0.006099
# Epoch [698 / 1000] average reconstruction error: 0.005918
# Epoch [699 / 1000] average reconstruction error: 0.006109
# Epoch [700 / 1000] average reconstruction error: 0.006005
# Epoch [701 / 1000] average reconstruction error: 0.006433
# Epoch [702 / 1000] average reconstruction error: 0.006262
# Epoch [703 / 1000] average reconstruction error: 0.006511
# Epoch [704 / 1000] average reconstruction error: 0.006436
# Epoch [705 / 1000] average reconstruction error: 0.006163
# Epoch [706 / 1000] average reconstruction error: 0.006154
# Epoch [707 / 1000] average reconstruction error: 0.006156
# Epoch [708 / 1000] average reconstruction error: 0.006437
# Epoch [709 / 1000] average reconstruction error: 0.006188
# Epoch [710 / 1000] average reconstruction error: 0.006290
# Epoch [711 / 1000] average reconstruction error: 0.006100
# Epoch [712 / 1000] average reconstruction error: 0.006531
# Epoch [713 / 1000] average reconstruction error: 0.006260
# Epoch [714 / 1000] average reconstruction error: 0.006200
# Epoch [715 / 1000] average reconstruction error: 0.006354
# Epoch [716 / 1000] average reconstruction error: 0.006273
# Epoch [717 / 1000] average reconstruction error: 0.006328
# Epoch [718 / 1000] average reconstruction error: 0.006296
# Epoch [719 / 1000] average reconstruction error: 0.006119
# Epoch [720 / 1000] average reconstruction error: 0.005867
# Epoch [721 / 1000] average reconstruction error: 0.006342
# Epoch [722 / 1000] average reconstruction error: 0.006400
# Epoch [723 / 1000] average reconstruction error: 0.006046
# Epoch [724 / 1000] average reconstruction error: 0.006124
# Epoch [725 / 1000] average reconstruction error: 0.006410
# Epoch [726 / 1000] average reconstruction error: 0.006621
# Epoch [727 / 1000] average reconstruction error: 0.006248
# Epoch [728 / 1000] average reconstruction error: 0.006061
# Epoch [729 / 1000] average reconstruction error: 0.006048
# Epoch [730 / 1000] average reconstruction error: 0.005981
# Epoch [731 / 1000] average reconstruction error: 0.005912
# Epoch [732 / 1000] average reconstruction error: 0.005971
# Epoch [733 / 1000] average reconstruction error: 0.006025
# Epoch [734 / 1000] average reconstruction error: 0.006201
# Epoch [735 / 1000] average reconstruction error: 0.006101
# Epoch [736 / 1000] average reconstruction error: 0.005993
# Epoch [737 / 1000] average reconstruction error: 0.006436
# Epoch [738 / 1000] average reconstruction error: 0.006543
# Epoch [739 / 1000] average reconstruction error: 0.006343
# Epoch [740 / 1000] average reconstruction error: 0.006713
# Epoch [741 / 1000] average reconstruction error: 0.006583
# Epoch [742 / 1000] average reconstruction error: 0.006120
# Epoch [743 / 1000] average reconstruction error: 0.006360
# Epoch [744 / 1000] average reconstruction error: 0.006034
# Epoch [745 / 1000] average reconstruction error: 0.006040
# Epoch [746 / 1000] average reconstruction error: 0.006166
# Epoch [747 / 1000] average reconstruction error: 0.006015
# Epoch [748 / 1000] average reconstruction error: 0.006373
# Epoch [749 / 1000] average reconstruction error: 0.006049
# Epoch [750 / 1000] average reconstruction error: 0.006079
# Epoch [751 / 1000] average reconstruction error: 0.006244
# Epoch [752 / 1000] average reconstruction error: 0.006186
# Epoch [753 / 1000] average reconstruction error: 0.006221
# Epoch [754 / 1000] average reconstruction error: 0.005928
# Epoch [755 / 1000] average reconstruction error: 0.006460
# Epoch [756 / 1000] average reconstruction error: 0.006278
# Epoch [757 / 1000] average reconstruction error: 0.006159
# Epoch [758 / 1000] average reconstruction error: 0.005942
# Epoch [759 / 1000] average reconstruction error: 0.005935
# Epoch [760 / 1000] average reconstruction error: 0.005704
# Epoch [761 / 1000] average reconstruction error: 0.006665
# Epoch [762 / 1000] average reconstruction error: 0.006884
# Epoch [763 / 1000] average reconstruction error: 0.006054
# Epoch [764 / 1000] average reconstruction error: 0.006020
# Epoch [765 / 1000] average reconstruction error: 0.006045
# Epoch [766 / 1000] average reconstruction error: 0.006364
# Epoch [767 / 1000] average reconstruction error: 0.006090
# Epoch [768 / 1000] average reconstruction error: 0.005914
# Epoch [769 / 1000] average reconstruction error: 0.006043
# Epoch [770 / 1000] average reconstruction error: 0.006013
# Epoch [771 / 1000] average reconstruction error: 0.006009
# Epoch [772 / 1000] average reconstruction error: 0.005886
# Epoch [773 / 1000] average reconstruction error: 0.005925
# Epoch [774 / 1000] average reconstruction error: 0.005753
# Epoch [775 / 1000] average reconstruction error: 0.006142
# Epoch [776 / 1000] average reconstruction error: 0.006053
# Epoch [777 / 1000] average reconstruction error: 0.005868
# Epoch [778 / 1000] average reconstruction error: 0.006182
# Epoch [779 / 1000] average reconstruction error: 0.006009
# Epoch [780 / 1000] average reconstruction error: 0.005856
# Epoch [781 / 1000] average reconstruction error: 0.006077
# Epoch [782 / 1000] average reconstruction error: 0.006104
# Epoch [783 / 1000] average reconstruction error: 0.006114
# Epoch [784 / 1000] average reconstruction error: 0.006244
# Epoch [785 / 1000] average reconstruction error: 0.006421
# Epoch [786 / 1000] average reconstruction error: 0.006255
# Epoch [787 / 1000] average reconstruction error: 0.006206
# Epoch [788 / 1000] average reconstruction error: 0.006120
# Epoch [789 / 1000] average reconstruction error: 0.005864
# Epoch [790 / 1000] average reconstruction error: 0.006004
# Epoch [791 / 1000] average reconstruction error: 0.005887
# Epoch [792 / 1000] average reconstruction error: 0.005860
# Epoch [793 / 1000] average reconstruction error: 0.006391
# Epoch [794 / 1000] average reconstruction error: 0.006215
# Epoch [795 / 1000] average reconstruction error: 0.006128
# Epoch [796 / 1000] average reconstruction error: 0.005989
# Epoch [797 / 1000] average reconstruction error: 0.006016
# Epoch [798 / 1000] average reconstruction error: 0.005837
# Epoch [799 / 1000] average reconstruction error: 0.005925
# Epoch [800 / 1000] average reconstruction error: 0.005972
# Epoch [801 / 1000] average reconstruction error: 0.005894
# Epoch [802 / 1000] average reconstruction error: 0.006128
# Epoch [803 / 1000] average reconstruction error: 0.006732
# Epoch [804 / 1000] average reconstruction error: 0.006336
# Epoch [805 / 1000] average reconstruction error: 0.005979
# Epoch [806 / 1000] average reconstruction error: 0.006009
# Epoch [807 / 1000] average reconstruction error: 0.006120
# Epoch [808 / 1000] average reconstruction error: 0.005921
# Epoch [809 / 1000] average reconstruction error: 0.006024
# Epoch [810 / 1000] average reconstruction error: 0.006330
# Epoch [811 / 1000] average reconstruction error: 0.006069
# Epoch [812 / 1000] average reconstruction error: 0.005941
# Epoch [813 / 1000] average reconstruction error: 0.005984
# Epoch [814 / 1000] average reconstruction error: 0.005616
# Epoch [815 / 1000] average reconstruction error: 0.005933
# Epoch [816 / 1000] average reconstruction error: 0.006140
# Epoch [817 / 1000] average reconstruction error: 0.005964
# Epoch [818 / 1000] average reconstruction error: 0.005782
# Epoch [819 / 1000] average reconstruction error: 0.005913
# Epoch [820 / 1000] average reconstruction error: 0.005679
# Epoch [821 / 1000] average reconstruction error: 0.005672
# Epoch [822 / 1000] average reconstruction error: 0.005862
# Epoch [823 / 1000] average reconstruction error: 0.005796
# Epoch [824 / 1000] average reconstruction error: 0.005943
# Epoch [825 / 1000] average reconstruction error: 0.005959
# Epoch [826 / 1000] average reconstruction error: 0.005719
# Epoch [827 / 1000] average reconstruction error: 0.005835
# Epoch [828 / 1000] average reconstruction error: 0.005762
# Epoch [829 / 1000] average reconstruction error: 0.005547
# Epoch [830 / 1000] average reconstruction error: 0.005986
# Epoch [831 / 1000] average reconstruction error: 0.005943
# Epoch [832 / 1000] average reconstruction error: 0.005942
# Epoch [833 / 1000] average reconstruction error: 0.006140
# Epoch [834 / 1000] average reconstruction error: 0.005748
# Epoch [835 / 1000] average reconstruction error: 0.006017
# Epoch [836 / 1000] average reconstruction error: 0.006133
# Epoch [837 / 1000] average reconstruction error: 0.005768
# Epoch [838 / 1000] average reconstruction error: 0.005888
# Epoch [839 / 1000] average reconstruction error: 0.006424
# Epoch [840 / 1000] average reconstruction error: 0.005935
# Epoch [841 / 1000] average reconstruction error: 0.005840
# Epoch [842 / 1000] average reconstruction error: 0.005818
# Epoch [843 / 1000] average reconstruction error: 0.005747
# Epoch [844 / 1000] average reconstruction error: 0.005923
# Epoch [845 / 1000] average reconstruction error: 0.005712
# Epoch [846 / 1000] average reconstruction error: 0.006085
# Epoch [847 / 1000] average reconstruction error: 0.005836
# Epoch [848 / 1000] average reconstruction error: 0.005854
# Epoch [849 / 1000] average reconstruction error: 0.005964
# Epoch [850 / 1000] average reconstruction error: 0.006132
# Epoch [851 / 1000] average reconstruction error: 0.005785
# Epoch [852 / 1000] average reconstruction error: 0.006167
# Epoch [853 / 1000] average reconstruction error: 0.006145
# Epoch [854 / 1000] average reconstruction error: 0.005769
# Epoch [855 / 1000] average reconstruction error: 0.005700
# Epoch [856 / 1000] average reconstruction error: 0.005804
# Epoch [857 / 1000] average reconstruction error: 0.005807
# Epoch [858 / 1000] average reconstruction error: 0.006020
# Epoch [859 / 1000] average reconstruction error: 0.005685
# Epoch [860 / 1000] average reconstruction error: 0.006086
# Epoch [861 / 1000] average reconstruction error: 0.006424
# Epoch [862 / 1000] average reconstruction error: 0.006028
# Epoch [863 / 1000] average reconstruction error: 0.006300
# Epoch [864 / 1000] average reconstruction error: 0.006180
# Epoch [865 / 1000] average reconstruction error: 0.005950
# Epoch [866 / 1000] average reconstruction error: 0.005944
# Epoch [867 / 1000] average reconstruction error: 0.005685
# Epoch [868 / 1000] average reconstruction error: 0.005790
# Epoch [869 / 1000] average reconstruction error: 0.005620
# Epoch [870 / 1000] average reconstruction error: 0.005655
# Epoch [871 / 1000] average reconstruction error: 0.005579
# Epoch [872 / 1000] average reconstruction error: 0.006116
# Epoch [873 / 1000] average reconstruction error: 0.006033
# Epoch [874 / 1000] average reconstruction error: 0.005694
# Epoch [875 / 1000] average reconstruction error: 0.005713
# Epoch [876 / 1000] average reconstruction error: 0.005805
# Epoch [877 / 1000] average reconstruction error: 0.005944
# Epoch [878 / 1000] average reconstruction error: 0.005833
# Epoch [879 / 1000] average reconstruction error: 0.005914
# Epoch [880 / 1000] average reconstruction error: 0.005907
# Epoch [881 / 1000] average reconstruction error: 0.005743
# Epoch [882 / 1000] average reconstruction error: 0.005949
# Epoch [883 / 1000] average reconstruction error: 0.005658
# Epoch [884 / 1000] average reconstruction error: 0.006080
# Epoch [885 / 1000] average reconstruction error: 0.006363
# Epoch [886 / 1000] average reconstruction error: 0.006123
# Epoch [887 / 1000] average reconstruction error: 0.006176
# Epoch [888 / 1000] average reconstruction error: 0.005821
# Epoch [889 / 1000] average reconstruction error: 0.005899
# Epoch [890 / 1000] average reconstruction error: 0.006235
# Epoch [891 / 1000] average reconstruction error: 0.006467
# Epoch [892 / 1000] average reconstruction error: 0.005694
# Epoch [893 / 1000] average reconstruction error: 0.005740
# Epoch [894 / 1000] average reconstruction error: 0.005945
# Epoch [895 / 1000] average reconstruction error: 0.005680
# Epoch [896 / 1000] average reconstruction error: 0.005683
# Epoch [897 / 1000] average reconstruction error: 0.006247
# Epoch [898 / 1000] average reconstruction error: 0.005854
# Epoch [899 / 1000] average reconstruction error: 0.005789
# Epoch [900 / 1000] average reconstruction error: 0.005741
# Epoch [901 / 1000] average reconstruction error: 0.005762
# Epoch [902 / 1000] average reconstruction error: 0.005710
# Epoch [903 / 1000] average reconstruction error: 0.005677
# Epoch [904 / 1000] average reconstruction error: 0.006088
# Epoch [905 / 1000] average reconstruction error: 0.006249
# Epoch [906 / 1000] average reconstruction error: 0.005991
# Epoch [907 / 1000] average reconstruction error: 0.005944
# Epoch [908 / 1000] average reconstruction error: 0.005953
# Epoch [909 / 1000] average reconstruction error: 0.006063
# Epoch [910 / 1000] average reconstruction error: 0.006016
# Epoch [911 / 1000] average reconstruction error: 0.005837
# Epoch [912 / 1000] average reconstruction error: 0.005761
# Epoch [913 / 1000] average reconstruction error: 0.005874
# Epoch [914 / 1000] average reconstruction error: 0.005715
# Epoch [915 / 1000] average reconstruction error: 0.005897
# Epoch [916 / 1000] average reconstruction error: 0.005831
# Epoch [917 / 1000] average reconstruction error: 0.005913
# Epoch [918 / 1000] average reconstruction error: 0.005678
# Epoch [919 / 1000] average reconstruction error: 0.005618
# Epoch [920 / 1000] average reconstruction error: 0.005735
# Epoch [921 / 1000] average reconstruction error: 0.005953
# Epoch [922 / 1000] average reconstruction error: 0.005776
# Epoch [923 / 1000] average reconstruction error: 0.005534
# Epoch [924 / 1000] average reconstruction error: 0.005816
# Epoch [925 / 1000] average reconstruction error: 0.005570
# Epoch [926 / 1000] average reconstruction error: 0.006055
# Epoch [927 / 1000] average reconstruction error: 0.005904
# Epoch [928 / 1000] average reconstruction error: 0.005670
# Epoch [929 / 1000] average reconstruction error: 0.005837
# Epoch [930 / 1000] average reconstruction error: 0.005549
# Epoch [931 / 1000] average reconstruction error: 0.005674
# Epoch [932 / 1000] average reconstruction error: 0.005723
# Epoch [933 / 1000] average reconstruction error: 0.005780
# Epoch [934 / 1000] average reconstruction error: 0.005553
# Epoch [935 / 1000] average reconstruction error: 0.005683
# Epoch [936 / 1000] average reconstruction error: 0.005477
# Epoch [937 / 1000] average reconstruction error: 0.005515
# Epoch [938 / 1000] average reconstruction error: 0.005658
# Epoch [939 / 1000] average reconstruction error: 0.005686
# Epoch [940 / 1000] average reconstruction error: 0.005791
# Epoch [941 / 1000] average reconstruction error: 0.005503
# Epoch [942 / 1000] average reconstruction error: 0.005706
# Epoch [943 / 1000] average reconstruction error: 0.005877
# Epoch [944 / 1000] average reconstruction error: 0.006197
# Epoch [945 / 1000] average reconstruction error: 0.005853
# Epoch [946 / 1000] average reconstruction error: 0.005751
# Epoch [947 / 1000] average reconstruction error: 0.005667
# Epoch [948 / 1000] average reconstruction error: 0.005770
# Epoch [949 / 1000] average reconstruction error: 0.005892
# Epoch [950 / 1000] average reconstruction error: 0.005725
# Epoch [951 / 1000] average reconstruction error: 0.005374
# Epoch [952 / 1000] average reconstruction error: 0.005541
# Epoch [953 / 1000] average reconstruction error: 0.005501
# Epoch [954 / 1000] average reconstruction error: 0.005851
# Epoch [955 / 1000] average reconstruction error: 0.005758
# Epoch [956 / 1000] average reconstruction error: 0.005697
# Epoch [957 / 1000] average reconstruction error: 0.005748
# Epoch [958 / 1000] average reconstruction error: 0.005521
# Epoch [959 / 1000] average reconstruction error: 0.005683
# Epoch [960 / 1000] average reconstruction error: 0.006377
# Epoch [961 / 1000] average reconstruction error: 0.005772
# Epoch [962 / 1000] average reconstruction error: 0.006130
# Epoch [963 / 1000] average reconstruction error: 0.005905
# Epoch [964 / 1000] average reconstruction error: 0.005622
# Epoch [965 / 1000] average reconstruction error: 0.005587
# Epoch [966 / 1000] average reconstruction error: 0.005623
# Epoch [967 / 1000] average reconstruction error: 0.005667
# Epoch [968 / 1000] average reconstruction error: 0.005655
# Epoch [969 / 1000] average reconstruction error: 0.005958
# Epoch [970 / 1000] average reconstruction error: 0.005635
# Epoch [971 / 1000] average reconstruction error: 0.005623
# Epoch [972 / 1000] average reconstruction error: 0.005989
# Epoch [973 / 1000] average reconstruction error: 0.005838
# Epoch [974 / 1000] average reconstruction error: 0.005493
# Epoch [975 / 1000] average reconstruction error: 0.005977
# Epoch [976 / 1000] average reconstruction error: 0.005901
# Epoch [977 / 1000] average reconstruction error: 0.005674
# Epoch [978 / 1000] average reconstruction error: 0.005713
# Epoch [979 / 1000] average reconstruction error: 0.005570
# Epoch [980 / 1000] average reconstruction error: 0.005825
# Epoch [981 / 1000] average reconstruction error: 0.005394
# Epoch [982 / 1000] average reconstruction error: 0.005514
# Epoch [983 / 1000] average reconstruction error: 0.005712
# Epoch [984 / 1000] average reconstruction error: 0.005673
# Epoch [985 / 1000] average reconstruction error: 0.005520
# Epoch [986 / 1000] average reconstruction error: 0.005916
# Epoch [987 / 1000] average reconstruction error: 0.005721
# Epoch [988 / 1000] average reconstruction error: 0.005451
# Epoch [989 / 1000] average reconstruction error: 0.005905
# Epoch [990 / 1000] average reconstruction error: 0.005718
# Epoch [991 / 1000] average reconstruction error: 0.005715
# Epoch [992 / 1000] average reconstruction error: 0.006100
# Epoch [993 / 1000] average reconstruction error: 0.005637
# Epoch [994 / 1000] average reconstruction error: 0.005931
# Epoch [995 / 1000] average reconstruction error: 0.005761
# Epoch [996 / 1000] average reconstruction error: 0.005869
# Epoch [997 / 1000] average reconstruction error: 0.005733
# Epoch [998 / 1000] average reconstruction error: 0.005995
# Epoch [999 / 1000] average reconstruction error: 0.005694
# Epoch [1000 / 1000] average reconstruction error: 0.005612

# %%
#visualize training plot
model_autoencoder.eval()
id=0
real_c=WaveSpeedData.data_wavespeed[id]
figlist=plot_3d(real_c)
data_input=torch.tensor(WaveSpeedData.data_wavespeed[id]).unsqueeze(0).unsqueeze(0).float().to(device)
re_c=model_autoencoder(data_input)[0].squeeze().clone().detach().cpu().numpy()
figlist=plot_3d(re_c)
print(((re_c-real_c)**2).mean())
# Out:
# 0.0067426255

# %%
#visualize test plot
model_autoencoder.eval()
id=1
real_c=WaveSpeedData.data_wavespeed_test[id]
figlist=plot_3d(real_c)
data_input=torch.tensor(WaveSpeedData.data_wavespeed_test[id]).unsqueeze(0).unsqueeze(0).float().to(device)
re_c=model_autoencoder(data_input)[0].squeeze().clone().detach().cpu().numpy()
figlist=plot_3d(re_c)
figlist=plot_3d(re_c-real_c)
print(((re_c-real_c)**2).mean())
# Out:
# 0.0020593684

# %% [markdown]
# ## Fit traveling time

# %%
L=6
scaler=get_latent(WaveSpeedData,model_autoencoder,device)
z_matrix_scale=scaler.scale_z(scaler.z_matrix)
z_matrix_test_scale=scaler.scale_z(scaler.z_matrix_test)
ttdata=traveling_time_dataset(WaveSpeedData,z_matrix_scale,z_matrix_test_scale,n_station,grid_size)
# Out:
# 100%|██████████| 5000/5000 [02:29<00:00, 33.50it/s]
# 100%|██████████| 100/100 [00:03<00:00, 30.48it/s]

# %%
batch_size_siren=20000
first_omega_0=15
hidden_omega_0=15
model_traveltime= Siren(in_features=3+L, out_features=n_station, hidden_features=512, 
                        hidden_layers=4, outermost_linear=True,first_omega_0=first_omega_0, hidden_omega_0=hidden_omega_0).to(device)
optimizer = torch.optim.Adam(model_traveltime.parameters(), lr=0.00001)
loss_function=torch.nn.MSELoss(reduction='mean')
train_loader = torch.utils.data.DataLoader(ttdata, batch_size=batch_size_siren, shuffle=True,num_workers=20)

# %%
# if torch.cuda.device_count() > 1:
#     print("Using", torch.cuda.device_count(), "GPUs!")
#     model_traveltime = torch.nn.DataParallel(model_traveltime)
# model_traveltime.to('cuda')

# %%
for epoch in range(100):
    model_traveltime.train()
    loss_batch = 0
    for data in tqdm(train_loader):
        X = data['in'].float().to(device)
        Y = data['out'].float().to(device)
        # X = data['in'].float().to('cuda')
        # Y = data['out'].float().to('cuda')
        Ypred,_= model_traveltime(X)
        loss = loss_function(Y, Ypred)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        loss_batch += loss.item()
    loss_epoch = loss_batch/len(train_loader)
    print(f'Epoch: {epoch:03d}, Train Loss: {loss_epoch:.2E}')
    torch.save(model_traveltime.state_dict(), 'save/model_traveltime.pt')
    if loss_epoch<1e-5:
        break
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /scicore/home/dokman0000/shi0000/GNNSEI/Association/unkown_wavespeed copy.ipynb Cell 15 in 2
#       <a href='vscode-notebook-cell://ssh-remote%2Bdgx1-dokmanic.scicore.unibas.ch/scicore/home/dokman0000/shi0000/GNNSEI/Association/unkown_wavespeed%20copy.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> for epoch in range(100):
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bdgx1-dokmanic.scicore.unibas.ch/scicore/home/dokman0000/shi0000/GNNSEI/Association/unkown_wavespeed%20copy.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a>     model_traveltime.train()
#       <a href='vscode-notebook-cell://ssh-remote%2Bdgx1-dokmanic.scicore.unibas.ch/scicore/home/dokman0000/shi0000/GNNSEI/Association/unkown_wavespeed%20copy.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a>     loss_batch = 0
#       <a href='vscode-notebook-cell://ssh-remote%2Bdgx1-dokmanic.scicore.unibas.ch/scicore/home/dokman0000/shi0000/GNNSEI/Association/unkown_wavespeed%20copy.ipynb#X20sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a>     for data in tqdm(train_loader):
#
# NameError: name 'model_traveltime' is not defined

# %%
# model_traveltime=model_traveltime.module.to(device)
# torch.cuda.empty_cache()
# del X
# del Y

# %% [markdown]
# ## Generate earthquake dataset

# %%
n_earthquake=8
tau_max=0.5 #1=10s
loc_earthquake_index=np.random.randint(grid_size,size=[n_earthquake,3])
tt=ttdata.data_test[id].reshape(n_station,grid_size,grid_size,grid_size)
true_receiver= tt[:,loc_earthquake_index[:,0],loc_earthquake_index[:,1],loc_earthquake_index[:,2]]
loc_earthquake_coord=loc_earthquake_index/(grid_size-1)
time_earthquake = np.random.rand(n_earthquake)*tau_max

## received signal is sorted
true_station_travelingtime=np.zeros_like(true_receiver)
true_station_travelingtime_index=np.zeros_like(true_receiver,dtype=int)
for i in range(n_station):
    true_receiver[i,:]=true_receiver[i,:]+time_earthquake
    true_station_travelingtime[i,:]=np.sort(true_receiver[i,:])
    true_station_travelingtime_index[i,:]=np.argsort(true_receiver[i,:])
z_truth=ttdata.output_test(id)['z']

# %% [markdown]
# ## Init our model

# %%
for try_i in range(1000): # usually need 1~5 trials 
    loc_record_list=[]
    lowest_loss=100000
    updata_lr_flag=True    
    #L=4 #dimention of the wave speed, for fixed wave speed, L=0
    batch_size=100
    model_traveltime_=copy.deepcopy(model_traveltime).to(device)
    AModel=AssignmentModel(model_traveltime_, n_station, n_earthquake,tau_max,L=L).to(device)
    #AModel=AssignmentModel(model_traveltime_, n_station, n_earthquake,tau_max,L=L,cheat=True,loc_earthquake_truth=loc_earthquake_coord,time_earthquake_truth=time_earthquake,z_truth=z_truth).to(device)
    # In cheat mode, the parameters will be initialized around the grount truth.  This is used to check whether the SIREN and auto-encoder are well trained.
    optimizer = SGLD(AModel.parameters(), lr=0.01,noise=1e-3)
    loc_earthquake_re=AModel.loc_earthquake.detach().clone().cpu().numpy()
    loc_record_list.append(loc_earthquake_re)
    for epoch in range(30):
        loss_batch = 0
        count=0
        for count in range(batch_size):
            i=np.random.randint(n_station) ## update one station at each time 
            out=AModel().T
            outi=out[i,:]
            Y=torch.tensor(true_station_travelingtime[i,:]).float().to(device)
            loss = wasserstein_1d(outi, Y, p=2)
            loss_batch += loss.item()
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
        loss_epoch = loss_batch/batch_size
        
        ## change hp
        if loss_epoch<0.005 and updata_lr_flag:
            updata_lr_flag=False
            optimizer = SGLD(AModel.parameters(), lr=0.001,noise=1e-4)            
        
        ## val test
        loc_earthquake_re=AModel.loc_earthquake.detach().clone().cpu().numpy()
        loc_record_list.append(loc_earthquake_re)
        indexB=greed_assignment(loc_earthquake_coord,loc_earthquake_re)  # only check the test perfermance roughly
        loc_error=((loc_earthquake_coord[indexB,:]-loc_earthquake_re)**2).mean()
        time_earthquake_re=AModel.time_earthquake.detach().clone().cpu().numpy()
        time_error=(((time_earthquake[indexB]-time_earthquake_re))**2).mean()
        z=AModel.z.detach().clone().cpu().numpy()
        z_error=np.mean((z-z_truth)**2)
        if loss_epoch <lowest_loss:
            lowest_loss= loss_epoch
            lowest_loss_loc_earthquake_re = loc_earthquake_re
            lowest_loss_time_earthquake_re = time_earthquake_re
            lowest_loss_out = AModel(sort_out=False).clone().detach().cpu().numpy().T
        
        print(f'Try: {try_i:03d},Epoch: {epoch:03d}, Loss: {loss_epoch:.6f}, Loc error: {loc_error:.6f}, Time error: {time_error:.6f}, Z error: {z_error:.6f}')
    if lowest_loss<0.001:
            break

## training with a small learning rate to get a better reconstruction.
optimizer = SGLD(AModel.parameters(), lr=0.0001,noise=1e-5)            
for epoch in range(50):
    loss_batch = 0
    count=0
    for count in range(batch_size):
        i=np.random.randint(n_station) ## update one station at each time 
        out=AModel().T
        outi=out[i,:]
        Y=torch.tensor(true_station_travelingtime[i,:]).float().to(device)
        loss = wasserstein_1d(outi, Y, p=2)
        loss_batch += loss.item()
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    loss_epoch = loss_batch/batch_size
    
    ## val test
    loc_earthquake_re=AModel.loc_earthquake.detach().clone().cpu().numpy()
    loc_record_list.append(loc_earthquake_re)
    indexB=greed_assignment(loc_earthquake_coord,loc_earthquake_re)  # only check the test perfermance roughly
    loc_error=((loc_earthquake_coord[indexB,:]-loc_earthquake_re)**2).mean()
    time_earthquake_re=AModel.time_earthquake.detach().clone().cpu().numpy()
    time_error=(((time_earthquake[indexB]-time_earthquake_re))**2).mean()
    if loss_epoch <lowest_loss:
        lowest_loss= loss_epoch
        lowest_loss_loc_earthquake_re = loc_earthquake_re
        lowest_loss_time_earthquake_re = time_earthquake_re
        lowest_loss_out = AModel(sort_out=False).clone().detach().cpu().numpy().T
    print(f'Try: {try_i:03d},Epoch: {epoch:03d}, Loss: {loss_epoch:.6f}, Loc error: {loc_error:.6f}, Time error: {time_error:.6f}, Z error: {z_error:.6f}')
# Out:
# Try: 000,Epoch: 000, Loss: 0.013284, Loc error: 0.010317, Time error: 0.001785, Z error: 0.062374
# Try: 000,Epoch: 001, Loss: 0.006766, Loc error: 0.012301, Time error: 0.000792, Z error: 0.045008
# Try: 000,Epoch: 002, Loss: 0.004265, Loc error: 0.012457, Time error: 0.001370, Z error: 0.027733
# Try: 000,Epoch: 003, Loss: 0.002124, Loc error: 0.011281, Time error: 0.001060, Z error: 0.026922
# Try: 000,Epoch: 004, Loss: 0.001782, Loc error: 0.011504, Time error: 0.000932, Z error: 0.025665
# Try: 000,Epoch: 005, Loss: 0.001854, Loc error: 0.011726, Time error: 0.001104, Z error: 0.025838
# Try: 000,Epoch: 006, Loss: 0.001771, Loc error: 0.011225, Time error: 0.001091, Z error: 0.025535
# Try: 000,Epoch: 007, Loss: 0.001656, Loc error: 0.010475, Time error: 0.000957, Z error: 0.024710
# Try: 000,Epoch: 008, Loss: 0.001458, Loc error: 0.010071, Time error: 0.000914, Z error: 0.023410
# Try: 000,Epoch: 009, Loss: 0.001414, Loc error: 0.009706, Time error: 0.000927, Z error: 0.023563
# Try: 000,Epoch: 010, Loss: 0.001585, Loc error: 0.009224, Time error: 0.000961, Z error: 0.023116
# Try: 000,Epoch: 011, Loss: 0.001314, Loc error: 0.008641, Time error: 0.000905, Z error: 0.024136
# Try: 000,Epoch: 012, Loss: 0.001123, Loc error: 0.008454, Time error: 0.000885, Z error: 0.023088
# Try: 000,Epoch: 013, Loss: 0.001313, Loc error: 0.005857, Time error: 0.000839, Z error: 0.024074
# Try: 000,Epoch: 014, Loss: 0.001393, Loc error: 0.008495, Time error: 0.000841, Z error: 0.024064
# Try: 000,Epoch: 015, Loss: 0.001318, Loc error: 0.008796, Time error: 0.000821, Z error: 0.023245
# Try: 000,Epoch: 016, Loss: 0.001313, Loc error: 0.008471, Time error: 0.000880, Z error: 0.023429
# Try: 000,Epoch: 017, Loss: 0.001298, Loc error: 0.008152, Time error: 0.000933, Z error: 0.024364
# Try: 000,Epoch: 018, Loss: 0.001340, Loc error: 0.008259, Time error: 0.000860, Z error: 0.024486
# Try: 000,Epoch: 019, Loss: 0.001237, Loc error: 0.008334, Time error: 0.000705, Z error: 0.024464
# Try: 000,Epoch: 020, Loss: 0.001436, Loc error: 0.007969, Time error: 0.000827, Z error: 0.024265
# Try: 000,Epoch: 021, Loss: 0.001223, Loc error: 0.008100, Time error: 0.000675, Z error: 0.024635
# Try: 000,Epoch: 022, Loss: 0.001243, Loc error: 0.008193, Time error: 0.000559, Z error: 0.025031
# Try: 000,Epoch: 023, Loss: 0.001174, Loc error: 0.008078, Time error: 0.000560, Z error: 0.025419
# Try: 000,Epoch: 024, Loss: 0.001307, Loc error: 0.008286, Time error: 0.000685, Z error: 0.024663
# Try: 000,Epoch: 025, Loss: 0.001124, Loc error: 0.007922, Time error: 0.000750, Z error: 0.024246
# Try: 000,Epoch: 026, Loss: 0.001319, Loc error: 0.008056, Time error: 0.000626, Z error: 0.024732
# Try: 000,Epoch: 027, Loss: 0.001326, Loc error: 0.008086, Time error: 0.000665, Z error: 0.024508
# Try: 000,Epoch: 028, Loss: 0.001344, Loc error: 0.008518, Time error: 0.000740, Z error: 0.024699
# Try: 000,Epoch: 029, Loss: 0.001289, Loc error: 0.008358, Time error: 0.000706, Z error: 0.024720
# Try: 001,Epoch: 000, Loss: 0.054096, Loc error: 0.106720, Time error: 0.001526, Z error: 0.029941
# Try: 001,Epoch: 001, Loss: 0.016861, Loc error: 0.089888, Time error: 0.001696, Z error: 0.043494
# Try: 001,Epoch: 002, Loss: 0.016189, Loc error: 0.085079, Time error: 0.001605, Z error: 0.051732
# Try: 001,Epoch: 003, Loss: 0.013768, Loc error: 0.081903, Time error: 0.001624, Z error: 0.067696
# Try: 001,Epoch: 004, Loss: 0.014095, Loc error: 0.081738, Time error: 0.001905, Z error: 0.063618
# Try: 001,Epoch: 005, Loss: 0.013933, Loc error: 0.073880, Time error: 0.002288, Z error: 0.074560
# Try: 001,Epoch: 006, Loss: 0.014069, Loc error: 0.072879, Time error: 0.000816, Z error: 0.062084
# Try: 001,Epoch: 007, Loss: 0.014072, Loc error: 0.072035, Time error: 0.001208, Z error: 0.065221
# Try: 001,Epoch: 008, Loss: 0.012090, Loc error: 0.069613, Time error: 0.002276, Z error: 0.064926
# Try: 001,Epoch: 009, Loss: 0.013861, Loc error: 0.066580, Time error: 0.001990, Z error: 0.067592
# Try: 001,Epoch: 010, Loss: 0.011767, Loc error: 0.067411, Time error: 0.002152, Z error: 0.067089
# Try: 001,Epoch: 011, Loss: 0.013657, Loc error: 0.076118, Time error: 0.000935, Z error: 0.066951
# Try: 001,Epoch: 012, Loss: 0.012123, Loc error: 0.073440, Time error: 0.001933, Z error: 0.067146
# Try: 001,Epoch: 013, Loss: 0.011141, Loc error: 0.070152, Time error: 0.001893, Z error: 0.066619
# Try: 001,Epoch: 014, Loss: 0.012541, Loc error: 0.070243, Time error: 0.002167, Z error: 0.063812
# Try: 001,Epoch: 015, Loss: 0.013392, Loc error: 0.068415, Time error: 0.000828, Z error: 0.064418
# Try: 001,Epoch: 016, Loss: 0.013187, Loc error: 0.069120, Time error: 0.001200, Z error: 0.070461
# Try: 001,Epoch: 017, Loss: 0.015358, Loc error: 0.063381, Time error: 0.001078, Z error: 0.061796
# Try: 001,Epoch: 018, Loss: 0.012441, Loc error: 0.069281, Time error: 0.000901, Z error: 0.069290
# Try: 001,Epoch: 019, Loss: 0.013166, Loc error: 0.073461, Time error: 0.001719, Z error: 0.074337
# Try: 001,Epoch: 020, Loss: 0.013271, Loc error: 0.071605, Time error: 0.002035, Z error: 0.067606
# Try: 001,Epoch: 021, Loss: 0.014228, Loc error: 0.071404, Time error: 0.002004, Z error: 0.074695
# Try: 001,Epoch: 022, Loss: 0.010832, Loc error: 0.076626, Time error: 0.001452, Z error: 0.073633
# Try: 001,Epoch: 023, Loss: 0.011427, Loc error: 0.072886, Time error: 0.002840, Z error: 0.065339
# Try: 001,Epoch: 024, Loss: 0.012103, Loc error: 0.048121, Time error: 0.000865, Z error: 0.080795
# Try: 001,Epoch: 025, Loss: 0.010679, Loc error: 0.046510, Time error: 0.000801, Z error: 0.079396
# Try: 001,Epoch: 026, Loss: 0.011014, Loc error: 0.051691, Time error: 0.000447, Z error: 0.077708
# Try: 001,Epoch: 027, Loss: 0.009852, Loc error: 0.050918, Time error: 0.000414, Z error: 0.082297
# Try: 001,Epoch: 028, Loss: 0.009813, Loc error: 0.050407, Time error: 0.001138, Z error: 0.089701
# Try: 001,Epoch: 029, Loss: 0.011389, Loc error: 0.065440, Time error: 0.001010, Z error: 0.111727
# Try: 002,Epoch: 000, Loss: 0.026992, Loc error: 0.036703, Time error: 0.001551, Z error: 0.018806
# Try: 002,Epoch: 001, Loss: 0.006218, Loc error: 0.029079, Time error: 0.002009, Z error: 0.021191
# Try: 002,Epoch: 002, Loss: 0.005004, Loc error: 0.025626, Time error: 0.001419, Z error: 0.015614
# Try: 002,Epoch: 003, Loss: 0.003474, Loc error: 0.019891, Time error: 0.001098, Z error: 0.004953
# Try: 002,Epoch: 004, Loss: 0.002289, Loc error: 0.019781, Time error: 0.001133, Z error: 0.005528
# Try: 002,Epoch: 005, Loss: 0.001924, Loc error: 0.018799, Time error: 0.001609, Z error: 0.004541
# Try: 002,Epoch: 006, Loss: 0.001652, Loc error: 0.018400, Time error: 0.001406, Z error: 0.005318
# Try: 002,Epoch: 007, Loss: 0.001667, Loc error: 0.017415, Time error: 0.001417, Z error: 0.005362
# Try: 002,Epoch: 008, Loss: 0.001800, Loc error: 0.016297, Time error: 0.001425, Z error: 0.004774
# Try: 002,Epoch: 009, Loss: 0.001780, Loc error: 0.015410, Time error: 0.001403, Z error: 0.004622
# Try: 002,Epoch: 010, Loss: 0.001393, Loc error: 0.015168, Time error: 0.001448, Z error: 0.004383
# Try: 002,Epoch: 011, Loss: 0.001416, Loc error: 0.014492, Time error: 0.001387, Z error: 0.004660
# Try: 002,Epoch: 012, Loss: 0.001634, Loc error: 0.013760, Time error: 0.001310, Z error: 0.004202
# Try: 002,Epoch: 013, Loss: 0.001560, Loc error: 0.013282, Time error: 0.001530, Z error: 0.004573
# Try: 002,Epoch: 014, Loss: 0.001501, Loc error: 0.012038, Time error: 0.001500, Z error: 0.004751
# Try: 002,Epoch: 015, Loss: 0.001338, Loc error: 0.010698, Time error: 0.001318, Z error: 0.004705
# Try: 002,Epoch: 016, Loss: 0.001461, Loc error: 0.009680, Time error: 0.001505, Z error: 0.004723
# Try: 002,Epoch: 017, Loss: 0.001198, Loc error: 0.008901, Time error: 0.001298, Z error: 0.004190
# Try: 002,Epoch: 018, Loss: 0.001292, Loc error: 0.007836, Time error: 0.001437, Z error: 0.004315
# Try: 002,Epoch: 019, Loss: 0.001299, Loc error: 0.006967, Time error: 0.001393, Z error: 0.004313
# Try: 002,Epoch: 020, Loss: 0.001178, Loc error: 0.006565, Time error: 0.001487, Z error: 0.004408
# Try: 002,Epoch: 021, Loss: 0.001045, Loc error: 0.005853, Time error: 0.001532, Z error: 0.004287
# Try: 002,Epoch: 022, Loss: 0.001034, Loc error: 0.005031, Time error: 0.001307, Z error: 0.002916
# Try: 002,Epoch: 023, Loss: 0.000815, Loc error: 0.004142, Time error: 0.001511, Z error: 0.002305
# Try: 002,Epoch: 024, Loss: 0.000755, Loc error: 0.003270, Time error: 0.001536, Z error: 0.001719
# Try: 002,Epoch: 025, Loss: 0.000702, Loc error: 0.002641, Time error: 0.001516, Z error: 0.001026
# Try: 002,Epoch: 026, Loss: 0.000520, Loc error: 0.001943, Time error: 0.001468, Z error: 0.000757
# Try: 002,Epoch: 027, Loss: 0.000500, Loc error: 0.001614, Time error: 0.001392, Z error: 0.000572
# Try: 002,Epoch: 028, Loss: 0.000424, Loc error: 0.001530, Time error: 0.001336, Z error: 0.000504
# Try: 002,Epoch: 029, Loss: 0.000477, Loc error: 0.001580, Time error: 0.001405, Z error: 0.000398
# Try: 002,Epoch: 000, Loss: 0.000335, Loc error: 0.001580, Time error: 0.001399, Z error: 0.000398
# Try: 002,Epoch: 001, Loss: 0.000356, Loc error: 0.001565, Time error: 0.001416, Z error: 0.000398
# Try: 002,Epoch: 002, Loss: 0.000359, Loc error: 0.001524, Time error: 0.001421, Z error: 0.000398
# Try: 002,Epoch: 003, Loss: 0.000393, Loc error: 0.001527, Time error: 0.001420, Z error: 0.000398
# Try: 002,Epoch: 004, Loss: 0.000323, Loc error: 0.001520, Time error: 0.001412, Z error: 0.000398
# Try: 002,Epoch: 005, Loss: 0.000341, Loc error: 0.001511, Time error: 0.001417, Z error: 0.000398
# Try: 002,Epoch: 006, Loss: 0.000358, Loc error: 0.001513, Time error: 0.001410, Z error: 0.000398
# Try: 002,Epoch: 007, Loss: 0.000464, Loc error: 0.001522, Time error: 0.001424, Z error: 0.000398
# Try: 002,Epoch: 008, Loss: 0.000335, Loc error: 0.001514, Time error: 0.001416, Z error: 0.000398
# Try: 002,Epoch: 009, Loss: 0.000421, Loc error: 0.001521, Time error: 0.001412, Z error: 0.000398
# Try: 002,Epoch: 010, Loss: 0.000366, Loc error: 0.001514, Time error: 0.001403, Z error: 0.000398
# Try: 002,Epoch: 011, Loss: 0.000348, Loc error: 0.001497, Time error: 0.001418, Z error: 0.000398
# Try: 002,Epoch: 012, Loss: 0.000306, Loc error: 0.001487, Time error: 0.001401, Z error: 0.000398
# Try: 002,Epoch: 013, Loss: 0.000346, Loc error: 0.001472, Time error: 0.001351, Z error: 0.000398
# Try: 002,Epoch: 014, Loss: 0.000335, Loc error: 0.001453, Time error: 0.001368, Z error: 0.000398
# Try: 002,Epoch: 015, Loss: 0.000306, Loc error: 0.001421, Time error: 0.001421, Z error: 0.000398
# Try: 002,Epoch: 016, Loss: 0.000355, Loc error: 0.001442, Time error: 0.001412, Z error: 0.000398
# Try: 002,Epoch: 017, Loss: 0.000329, Loc error: 0.001444, Time error: 0.001403, Z error: 0.000398
# Try: 002,Epoch: 018, Loss: 0.000356, Loc error: 0.001439, Time error: 0.001406, Z error: 0.000398
# Try: 002,Epoch: 019, Loss: 0.000367, Loc error: 0.001429, Time error: 0.001416, Z error: 0.000398
# Try: 002,Epoch: 020, Loss: 0.000354, Loc error: 0.001445, Time error: 0.001396, Z error: 0.000398
# Try: 002,Epoch: 021, Loss: 0.000427, Loc error: 0.001460, Time error: 0.001398, Z error: 0.000398
# Try: 002,Epoch: 022, Loss: 0.000398, Loc error: 0.001458, Time error: 0.001409, Z error: 0.000398
# Try: 002,Epoch: 023, Loss: 0.000335, Loc error: 0.001450, Time error: 0.001381, Z error: 0.000398
# Try: 002,Epoch: 024, Loss: 0.000402, Loc error: 0.001469, Time error: 0.001388, Z error: 0.000398
# Try: 002,Epoch: 025, Loss: 0.000367, Loc error: 0.001475, Time error: 0.001379, Z error: 0.000398
# Try: 002,Epoch: 026, Loss: 0.000373, Loc error: 0.001469, Time error: 0.001378, Z error: 0.000398
# Try: 002,Epoch: 027, Loss: 0.000351, Loc error: 0.001451, Time error: 0.001378, Z error: 0.000398
# Try: 002,Epoch: 028, Loss: 0.000426, Loc error: 0.001462, Time error: 0.001406, Z error: 0.000398
# Try: 002,Epoch: 029, Loss: 0.000352, Loc error: 0.001447, Time error: 0.001384, Z error: 0.000398
# Try: 002,Epoch: 030, Loss: 0.000340, Loc error: 0.001449, Time error: 0.001402, Z error: 0.000398
# Try: 002,Epoch: 031, Loss: 0.000385, Loc error: 0.001460, Time error: 0.001420, Z error: 0.000398
# Try: 002,Epoch: 032, Loss: 0.000399, Loc error: 0.001472, Time error: 0.001407, Z error: 0.000398
# Try: 002,Epoch: 033, Loss: 0.000340, Loc error: 0.001471, Time error: 0.001392, Z error: 0.000398
# Try: 002,Epoch: 034, Loss: 0.000285, Loc error: 0.001448, Time error: 0.001339, Z error: 0.000398
# Try: 002,Epoch: 035, Loss: 0.000367, Loc error: 0.001439, Time error: 0.001347, Z error: 0.000398
# Try: 002,Epoch: 036, Loss: 0.000422, Loc error: 0.001442, Time error: 0.001400, Z error: 0.000398
# Try: 002,Epoch: 037, Loss: 0.000336, Loc error: 0.001426, Time error: 0.001401, Z error: 0.000398
# Try: 002,Epoch: 038, Loss: 0.000367, Loc error: 0.001426, Time error: 0.001405, Z error: 0.000398
# Try: 002,Epoch: 039, Loss: 0.000423, Loc error: 0.001449, Time error: 0.001409, Z error: 0.000398
# Try: 002,Epoch: 040, Loss: 0.000326, Loc error: 0.001428, Time error: 0.001397, Z error: 0.000398
# Try: 002,Epoch: 041, Loss: 0.000438, Loc error: 0.001437, Time error: 0.001409, Z error: 0.000398
# Try: 002,Epoch: 042, Loss: 0.000317, Loc error: 0.001414, Time error: 0.001396, Z error: 0.000398
# Try: 002,Epoch: 043, Loss: 0.000286, Loc error: 0.001391, Time error: 0.001386, Z error: 0.000398
# Try: 002,Epoch: 044, Loss: 0.000295, Loc error: 0.001383, Time error: 0.001371, Z error: 0.000398
# Try: 002,Epoch: 045, Loss: 0.000369, Loc error: 0.001393, Time error: 0.001392, Z error: 0.000398
# Try: 002,Epoch: 046, Loss: 0.000450, Loc error: 0.001438, Time error: 0.001413, Z error: 0.000398
# Try: 002,Epoch: 047, Loss: 0.000369, Loc error: 0.001442, Time error: 0.001413, Z error: 0.000398
# Try: 002,Epoch: 048, Loss: 0.000363, Loc error: 0.001436, Time error: 0.001406, Z error: 0.000398
# Try: 002,Epoch: 049, Loss: 0.000413, Loc error: 0.001465, Time error: 0.001404, Z error: 0.000398

# %%
from scipy.optimize import quadratic_assignment
from scipy.spatial import distance_matrix

assignment_function=greed_assignment

plt.rcParams.update({'font.size': 14})
indexB=assignment_function(loc_earthquake_coord,loc_earthquake_re)  #to get a order
plt.figure(figsize=(6.4, 4.8))
Crange=range(n_earthquake)
xaxis_max=lowest_loss_out.max()*1.1
cmap = plt.cm.get_cmap('Dark2', n_earthquake)
correct_rate=0
for i in range(n_station):
    yaxis_i=np.ones(n_earthquake)*i
    tx=true_station_travelingtime[i,]
    ti=true_station_travelingtime_index[i,:]
    out=lowest_loss_out[i,:]
    indexBi=assignment_function(out.reshape(-1,1),tx.reshape(-1,1))
    plt.plot([0,xaxis_max*9.5],[i,i],'-b',alpha=0.1)
    plt.scatter(tx*10,yaxis_i,marker='o', facecolors='none',s=50,alpha=1,edgecolors=cmap(ti[Crange]))
    plt.scatter(tx*10,yaxis_i,cmap=cmap,c=indexB[indexBi[Crange]],s=10,alpha=1)
    correct_rate+=np.mean(ti[Crange]==indexB[indexBi[Crange]])
cbar=plt.colorbar()
plt.xlabel('Time (s)')
plt.yticks([])
cbar.ax.tick_params(length=0)
cbar.set_ticks([])
print('Accuracy:',correct_rate/n_station)
# Out:
# Accuracy: 0.81875

# %%
# plot wave speed reconstrcuction
plt.rcParams.update({'font.size': 10})
z0=AModel.z.detach().clone().cpu().numpy()
z_re=scaler.scale_z_inv(z0)
z_re=torch.tensor(z_re).float().to(device)

V_re=model_autoencoder.decoder(z_re.reshape(1,-1)).detach().clone().cpu().numpy()[0][0]
figlist=plot_3d(real_c)
figlist=plot_3d(V_re)
ax0=figlist[1]
ax1=figlist[2]

#plt.subplots_adjust(wspace=0)
loc_earthquake_re=AModel.loc_earthquake.detach().clone().cpu().numpy()
loc_earthquake=loc_earthquake_coord
cp=plt.cm.get_cmap('Accent', n_earthquake)


ax1.scatter(loc_earthquake_re[:,0]*(grid_size-1),loc_earthquake_re[:,1]*(grid_size-1),-loc_earthquake_re[:,2]*(grid_size-1),s=30,color='black',marker='o',label='Earthquake',depthshade=0,edgecolors='black')
ax1.scatter(loc_earthquake[:,0]*(grid_size-1),loc_earthquake[:,1]*(grid_size-1),-loc_earthquake[:,2]*(grid_size-1),s=30,color='white',marker='^',label='Earthquake',depthshade=0,edgecolors='black')
coord=ttdata.loc_src_coord*grid_size
ax0.scatter3D(coord[:,0],coord[:,1],coord[:,2],s=20,depthshade=0,zorder=1e20,marker=(5, 1),color='orange')
